# %%
import pandas as pd
import numpy as np
import datetime
from scipy.stats import skew

from sklearn.ensemble import IsolationForest
import seaborn as sns
import matplotlib.pyplot as plt

import warnings 
warnings.filterwarnings('ignore')

from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error, r2_score
import math
#Accessing performance using Cross Validation
from sklearn.model_selection import cross_validate
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import Lasso, Ridge
from sklearn import metrics
import pickle
# !pip install scikit-learn
# !pip install --upgrade joblib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\users\rajij\appdata\roaming\python\python311\site-packages (1.5.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\rajij\appdata\roaming\python\python311\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\rajij\appdata\roaming\python\python311\site-packages (from scikit-learn) (3.5.0)
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: joblib in c:\users\rajij\appdata\roaming\python\python311\site-packages (1.4.2)

# %%
#pip install --upgrade scikit-learn
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: scikit-learn in c:\programdata\anaconda3\lib\site-packages (1.2.2)
# Collecting scikit-learn
#   Using cached scikit_learn-1.5.2-cp311-cp311-win_amd64.whl.metadata (13 kB)
# Requirement already satisfied: numpy>=1.19.5 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\programdata\anaconda3\lib\site-packages (from scikit-learn) (1.11.4)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\rajij\appdata\roaming\python\python311\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\rajij\appdata\roaming\python\python311\site-packages (from scikit-learn) (3.5.0)
# Using cached scikit_learn-1.5.2-cp311-cp311-win_amd64.whl (11.0 MB)
# Installing collected packages: scikit-learn
# Successfully installed scikit-learn-1.5.2
# Note: you may need to restart the kernel to use updated packages.

# %%
print(sklearn.__version__)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(sklearn.__version__)
#
# NameError: name 'sklearn' is not defined

# %%
df_1= pd.read_csv('Resale Flat Prices (Based on Approval Date), 1990 - 1999.csv')

# %%
df_1.head()
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4  1990-01  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price
# 0            31.0        IMPROVED                 1977          9000
# 1            31.0        IMPROVED                 1977          6000
# 2            31.0        IMPROVED                 1977          8000
# 3            31.0        IMPROVED                 1977          6000
# 4            73.0  NEW GENERATION                 1976         47200

# %%
df_2= pd.read_csv('Resale Flat Prices (Based on Approval Date), 2000 - Feb 2012.csv')

# %%
df_2.head()
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  2000-01  ANG MO KIO    3 ROOM   170  ANG MO KIO AVE 4     07 TO 09
# 1  2000-01  ANG MO KIO    3 ROOM   174  ANG MO KIO AVE 4     04 TO 06
# 2  2000-01  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1     07 TO 09
# 3  2000-01  ANG MO KIO    3 ROOM   215  ANG MO KIO AVE 1     07 TO 09
# 4  2000-01  ANG MO KIO    3 ROOM   218  ANG MO KIO AVE 1     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price
# 0            69.0        Improved                 1986      147000.0
# 1            61.0        Improved                 1986      144000.0
# 2            73.0  New Generation                 1976      159000.0
# 3            73.0  New Generation                 1976      167000.0
# 4            67.0  New Generation                 1976      163000.0

# %%
df_3= pd.read_csv('Resale Flat Prices (Based on Registration Date), From Mar 2012 to Dec 2014.csv')
df_4= pd.read_csv('Resale Flat Prices (Based on Registration Date), From Jan 2015 to Dec 2016.csv')
df_5= pd.read_csv('Resale flat prices based on registration date from Jan-2017 onwards.csv')

# %%
df_3.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2012-03  ANG MO KIO    2 ROOM   172   ANG MO KIO AVE 4     06 TO 10
# 1  2012-03  ANG MO KIO    2 ROOM   510   ANG MO KIO AVE 8     01 TO 05
# 2  2012-03  ANG MO KIO    3 ROOM   610   ANG MO KIO AVE 4     06 TO 10
# 3  2012-03  ANG MO KIO    3 ROOM   474  ANG MO KIO AVE 10     01 TO 05
# 4  2012-03  ANG MO KIO    3 ROOM   604   ANG MO KIO AVE 5     06 TO 10
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price
# 0            45.0        Improved                 1986      250000.0
# 1            44.0        Improved                 1980      265000.0
# 2            68.0  New Generation                 1980      315000.0
# 3            67.0  New Generation                 1984      320000.0
# 4            67.0  New Generation                 1980      321000.0

# %%
df_4.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2015-01  ANG MO KIO    3 ROOM   174   ANG MO KIO AVE 4     07 TO 09
# 1  2015-01  ANG MO KIO    3 ROOM   541  ANG MO KIO AVE 10     01 TO 03
# 2  2015-01  ANG MO KIO    3 ROOM   163   ANG MO KIO AVE 4     01 TO 03
# 3  2015-01  ANG MO KIO    3 ROOM   446  ANG MO KIO AVE 10     01 TO 03
# 4  2015-01  ANG MO KIO    3 ROOM   557  ANG MO KIO AVE 10     07 TO 09
#
#    floor_area_sqm      flat_model  lease_commence_date  remaining_lease  \
# 0            60.0        Improved                 1986               70
# 1            68.0  New Generation                 1981               65
# 2            69.0  New Generation                 1980               64
# 3            68.0  New Generation                 1979               63
# 4            68.0  New Generation                 1980               64
#
#    resale_price
# 0      255000.0
# 1      275000.0
# 2      285000.0
# 3      290000.0
# 4      290000.0

# %%
df_5.head()
# Out:
#      month        town flat_type block        street_name storey_range  \
# 0  2017-01  ANG MO KIO    2 ROOM   406  ANG MO KIO AVE 10     10 TO 12
# 1  2017-01  ANG MO KIO    3 ROOM   108   ANG MO KIO AVE 4     01 TO 03
# 2  2017-01  ANG MO KIO    3 ROOM   602   ANG MO KIO AVE 5     01 TO 03
# 3  2017-01  ANG MO KIO    3 ROOM   465  ANG MO KIO AVE 10     04 TO 06
# 4  2017-01  ANG MO KIO    3 ROOM   601   ANG MO KIO AVE 5     01 TO 03
#
#    floor_area_sqm      flat_model  lease_commence_date     remaining_lease  \
# 0            44.0        Improved                 1979  61 years 04 months
# 1            67.0  New Generation                 1978  60 years 07 months
# 2            67.0  New Generation                 1980  62 years 05 months
# 3            68.0  New Generation                 1980   62 years 01 month
# 4            67.0  New Generation                 1980  62 years 05 months
#
#    resale_price
# 0      232000.0
# 1      250000.0
# 2      262000.0
# 3      265000.0
# 4      265000.0

# %%
df=pd.concat([df_1,df_2,df_3,df_4,df_5],ignore_index=True)
df.head()
# Out:
#      month        town flat_type block       street_name storey_range  \
# 0  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 1  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     04 TO 06
# 2  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     10 TO 12
# 3  1990-01  ANG MO KIO    1 ROOM   309  ANG MO KIO AVE 1     07 TO 09
# 4  1990-01  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1     04 TO 06
#
#    floor_area_sqm      flat_model  lease_commence_date  resale_price  \
# 0            31.0        IMPROVED                 1977        9000.0
# 1            31.0        IMPROVED                 1977        6000.0
# 2            31.0        IMPROVED                 1977        8000.0
# 3            31.0        IMPROVED                 1977        6000.0
# 4            73.0  NEW GENERATION                 1976       47200.0
#
#   remaining_lease
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN

# %%
df[['year', 'month']] = df['month'].str.split('-', expand=True)
df[['storey_start', 'storey_end']] = df['storey_range'].str.split('TO',expand=True)
df['month']=pd.to_numeric(df['month'])
df['year']=pd.to_numeric(df['year'])
df['floor_area_sqm']=pd.to_numeric(df['floor_area_sqm'])
df['resale_price']=pd.to_numeric(df['resale_price'])
df['storey_start']=pd.to_numeric(df['storey_start'])
df['storey_end']=pd.to_numeric(df['storey_end'])

df.drop(columns='storey_range',inplace=True)

# %%
df.shape
# Out:
# (938269, 13)

# %%
df.dtypes
# Out:
# month                    int64
# town                    object
# flat_type               object
# block                   object
# street_name             object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# remaining_lease         object
# year                     int64
# storey_start             int64
# storey_end               int64
# dtype: object

# %%
df['town'].value_counts()
# Out:
# town
# TAMPINES           80722
# YISHUN             70785
# JURONG WEST        67442
# BEDOK              67182
# WOODLANDS          66336
# ANG MO KIO         52528
# HOUGANG            51317
# BUKIT BATOK        45128
# CHOA CHU KANG      38837
# BUKIT MERAH        34767
# PASIR RIS          33475
# SENGKANG           33354
# TOA PAYOH          31870
# QUEENSTOWN         29063
# GEYLANG            28468
# CLEMENTI           28268
# BUKIT PANJANG      28039
# KALLANG/WHAMPOA    27613
# JURONG EAST        25010
# SERANGOON          23008
# PUNGGOL            21490
# BISHAN             21425
# SEMBAWANG          14219
# MARINE PARADE       8097
# CENTRAL AREA        7218
# BUKIT TIMAH         2544
# LIM CHU KANG          64
# Name: count, dtype: int64

# %%
df['town']=df['town'].replace({'MARINE PARADE': 'Others'})
df['town']=df['town'].replace({'CENTRAL AREA': 'Others'})
df['town']=df['town'].replace({'BUKIT TIMAH': 'Others'})
df['town']=df['town'].replace({'LIM CHU KANG': 'Others'})

# %%
sorted(df['town'].unique())
# Out:
# ['ANG MO KIO',
#  'BEDOK',
#  'BISHAN',
#  'BUKIT BATOK',
#  'BUKIT MERAH',
#  'BUKIT PANJANG',
#  'CHOA CHU KANG',
#  'CLEMENTI',
#  'GEYLANG',
#  'HOUGANG',
#  'JURONG EAST',
#  'JURONG WEST',
#  'KALLANG/WHAMPOA',
#  'Others',
#  'PASIR RIS',
#  'PUNGGOL',
#  'QUEENSTOWN',
#  'SEMBAWANG',
#  'SENGKANG',
#  'SERANGOON',
#  'TAMPINES',
#  'TOA PAYOH',
#  'WOODLANDS',
#  'YISHUN']

# %%
df['flat_type'].unique()
# Out:
# array(['1 ROOM', '3 ROOM', '4 ROOM', '5 ROOM', '2 ROOM', 'EXECUTIVE',
#        'MULTI GENERATION', 'MULTI-GENERATION'], dtype=object)

# %%
df['flat_type'].value_counts()
# Out:
# flat_type
# 4 ROOM              357125
# 3 ROOM              298695
# 5 ROOM              198050
# EXECUTIVE            70386
# 2 ROOM               12162
# 1 ROOM                1307
# MULTI GENERATION       279
# MULTI-GENERATION       265
# Name: count, dtype: int64

# %%
df['flat_type']=df['flat_type'].replace({'EXECUTIVE': 'Others'})
df['flat_type']=df['flat_type'].replace({'2 ROOM': 'Others'})
df['flat_type']=df['flat_type'].replace({'1 ROOM': 'Others'})
df['flat_type']=df['flat_type'].replace({'MULTI GENERATION': 'Others'})
df['flat_type']=df['flat_type'].replace({'MULTI-GENERATION': 'Others'})

# %%
df['flat_type'].value_counts()
# Out:
# flat_type
# 4 ROOM    357125
# 3 ROOM    298695
# 5 ROOM    198050
# Others     84399
# Name: count, dtype: int64

# %%
df['flat_type'].unique()
# Out:
# array(['Others', '3 ROOM', '4 ROOM', '5 ROOM'], dtype=object)

# %%
df['street_name'].value_counts()
# Out:
# street_name
# YISHUN RING RD        17742
# BEDOK RESERVOIR RD    14834
# ANG MO KIO AVE 10     13913
# ANG MO KIO AVE 3      12240
# HOUGANG AVE 8          9419
#                       ...
# SENGKANG WEST RD          5
# MARINE PARADE CTRL        3
# TAMPINES NTH DR 1         3
# CANBERRA VIEW             2
# ALJUNIED AVE 2            1
# Name: count, Length: 588, dtype: int64

# %%
v_c = df['street_name'].value_counts()
freq = (v_c[v_c<5000]).index

unique_once_list = list(freq)
unique_once_list
# Out:
# ['YISHUN ST 11',
#  'YISHUN ST 21',
#  'JURONG WEST ST 81',
#  'WOODLANDS ST 13',
#  'YISHUN ST 61',
#  'BISHAN ST 13',
#  'JURONG WEST ST 52',
#  'UBI AVE 1',
#  'YISHUN ST 81',
#  'TECK WHYE LANE',
#  'PASIR RIS ST 21',
#  'TAMPINES ST 41',
#  'YISHUN AVE 6',
#  'JURONG WEST ST 41',
#  'BISHAN ST 12',
#  'PASIR RIS DR 6',
#  'SERANGOON NTH AVE 1',
#  'PASIR RIS ST 11',
#  'CHOA CHU KANG AVE 4',
#  'CHOA CHU KANG CRES',
#  'HOUGANG AVE 10',
#  'WOODLANDS RING RD',
#  'BOON LAY PL',
#  'HOUGANG AVE 1',
#  'TEBAN GDNS RD',
#  'TAMPINES ST 83',
#  'JURONG WEST ST 65',
#  'BT BATOK EAST AVE 5',
#  'JURONG WEST ST 91',
#  'HOUGANG AVE 5',
#  'JURONG WEST AVE 1',
#  'CLEMENTI AVE 2',
#  'PASIR RIS ST 71',
#  'TANGLIN HALT RD',
#  'SERANGOON NTH AVE 4',
#  'YISHUN AVE 5',
#  'WOODLANDS CIRCLE',
#  'CLEMENTI WEST ST 2',
#  'YISHUN ST 72',
#  'PUNGGOL FIELD',
#  'YISHUN ST 22',
#  'BT BATOK ST 21',
#  'TAMPINES ST 81',
#  'BT PANJANG RING RD',
#  'BT BATOK ST 31',
#  'PETIR RD',
#  'YISHUN AVE 11',
#  'JURONG EAST ST 24',
#  'RIVERVALE DR',
#  'HOUGANG AVE 3',
#  'JELAPANG RD',
#  'YISHUN AVE 4',
#  'LOR 8 TOA PAYOH',
#  'WOODLANDS DR 50',
#  'TELOK BLANGAH CRES',
#  "C'WEALTH DR",
#  'WOODLANDS DR 14',
#  'JURONG WEST ST 61',
#  'CHOA CHU KANG AVE 3',
#  'CHOA CHU KANG CTRL',
#  'BOON LAY AVE',
#  'JLN BT MERAH',
#  'BT BATOK WEST AVE 8',
#  'NEW UPP CHANGI RD',
#  'TAMPINES ST 11',
#  'TAMPINES ST 45',
#  'CLEMENTI AVE 5',
#  'BT BATOK ST 52',
#  'SENJA RD',
#  'PENDING RD',
#  'TAMPINES ST 12',
#  'SERANGOON AVE 4',
#  'YISHUN ST 71',
#  'JURONG EAST ST 32',
#  'MARINE TER',
#  'POTONG PASIR AVE 1',
#  'PUNGGOL CTRL',
#  'TAMPINES ST 71',
#  'EUNOS CRES',
#  'PASIR RIS ST 51',
#  'TAMPINES ST 82',
#  'EDGEFIELD PLAINS',
#  'BOON LAY DR',
#  'PUNGGOL DR',
#  'TAMPINES ST 33',
#  'GHIM MOH RD',
#  'BEDOK NTH ST 2',
#  'BEDOK STH RD',
#  'LOR 7 TOA PAYOH',
#  'GEYLANG BAHRU',
#  'RIVERVALE CRES',
#  'WOODLANDS ST 41',
#  'BISHAN ST 22',
#  'WOODLANDS AVE 6',
#  'SERANGOON AVE 2',
#  'JURONG WEST ST 64',
#  'EDGEDALE PLAINS',
#  'HOUGANG ST 51',
#  'BEDOK NTH AVE 4',
#  'SERANGOON AVE 3',
#  'TAMPINES AVE 4',
#  'SERANGOON CTRL',
#  'BT BATOK EAST AVE 4',
#  'CLEMENTI AVE 3',
#  'TAMPINES ST 91',
#  'TAMPINES ST 42',
#  'MARINE CRES',
#  'WOODLANDS DR 16',
#  'WHAMPOA DR',
#  'TELOK BLANGAH DR',
#  'WOODLANDS ST 82',
#  'SEGAR RD',
#  'HOUGANG AVE 6',
#  'ANG MO KIO AVE 6',
#  'BT BATOK CTRL',
#  'MARINE DR',
#  'LOR 2 TOA PAYOH',
#  'WEST COAST RD',
#  'FERNVALE RD',
#  'FAJAR RD',
#  'BEDOK NTH AVE 2',
#  'ADMIRALTY DR',
#  'TOH GUAN RD',
#  'ALJUNIED CRES',
#  'HOUGANG ST 91',
#  'BEDOK NTH AVE 1',
#  'CHAI CHEE RD',
#  'TAMPINES ST 23',
#  'BEDOK NTH AVE 3',
#  'TELOK BLANGAH HTS',
#  'PASIR RIS DR 4',
#  'SEMBAWANG DR',
#  'BEDOK STH AVE 2',
#  'WOODLANDS AVE 1',
#  'CHAI CHEE ST',
#  'SIN MING AVE',
#  'UPP BOON KENG RD',
#  'TAMPINES ST 43',
#  'BT BATOK ST 34',
#  'LOR AH SOO',
#  'LOR 4 TOA PAYOH',
#  'WOODLANDS ST 83',
#  'TAMPINES ST 32',
#  'CLEMENTI WEST ST 1',
#  'LOR 5 TOA PAYOH',
#  'GANGSA RD',
#  'BISHAN ST 23',
#  'JURONG WEST CTRL 1',
#  'PASIR RIS ST 12',
#  'ANCHORVALE LINK',
#  'CHOA CHU KANG AVE 2',
#  'TOA PAYOH NTH',
#  'BANGKIT RD',
#  'HOUGANG AVE 4',
#  'JURONG EAST ST 13',
#  'WOODLANDS CRES',
#  'TAMPINES AVE 5',
#  'PANDAN GDNS',
#  'STIRLING RD',
#  'CANBERRA RD',
#  'COMPASSVALE ST',
#  'BT PURMEI RD',
#  'HOLLAND DR',
#  'CHOA CHU KANG ST 51',
#  'HOLLAND AVE',
#  'BENDEMEER RD',
#  'BISHAN ST 24',
#  'CHOA CHU KANG ST 62',
#  'MEI LING ST',
#  'BALAM RD',
#  'ANCHORVALE RD',
#  'ANG MO KIO AVE 8',
#  'WOODLANDS DR 75',
#  'MARSILING LANE',
#  'BT BATOK ST 33',
#  "ST. GEORGE'S RD",
#  'PASIR RIS ST 52',
#  "C'WEALTH CL",
#  'BT MERAH VIEW',
#  'SEMBAWANG CL',
#  'CHOA CHU KANG ST 52',
#  'COMPASSVALE WALK',
#  'HOLLAND CL',
#  'HOUGANG AVE 2',
#  'HOUGANG AVE 7',
#  'WOODLANDS ST 81',
#  'BT BATOK ST 32',
#  'HOUGANG ST 61',
#  'HAIG RD',
#  'TAMPINES ST 34',
#  'JURONG EAST AVE 1',
#  'TOH YI DR',
#  'DOVER CRES',
#  'WOODLANDS ST 31',
#  'CHOA CHU KANG AVE 5',
#  'BEDOK STH AVE 3',
#  'BT BATOK WEST AVE 4',
#  'BT BATOK EAST AVE 3',
#  'YISHUN CTRL',
#  'BEDOK NTH ST 1',
#  'YISHUN AVE 3',
#  'PUNGGOL PL',
#  'BT BATOK ST 11',
#  'FERNVALE LINK',
#  'TAMPINES AVE 9',
#  'SIMS DR',
#  'ADMIRALTY LINK',
#  'SHUNFU RD',
#  'JLN BATU',
#  'MCNAIR RD',
#  'MARSILING RISE',
#  'TAMPINES ST 84',
#  'JLN BAHAGIA',
#  'JURONG WEST ST 71',
#  'COMPASSVALE RD',
#  'PUNGGOL WALK',
#  "C'WEALTH CRES",
#  'TECK WHYE AVE',
#  'WOODLANDS AVE 4',
#  'CHOA CHU KANG NTH 6',
#  'HOUGANG AVE 9',
#  'SIMEI ST 4',
#  'JURONG EAST ST 31',
#  'STRATHMORE AVE',
#  'BEDOK STH AVE 1',
#  'JURONG WEST ST 92',
#  'PASIR RIS DR 10',
#  'BT BATOK WEST AVE 5',
#  'WOODLANDS DR 60',
#  'SENGKANG EAST WAY',
#  'WEST COAST DR',
#  'TAMPINES ST 24',
#  'CLEMENTI AVE 1',
#  'KIM KEAT AVE',
#  'PASIR RIS DR 1',
#  'HO CHING RD',
#  'JURONG WEST ST 93',
#  'WOODLANDS ST 32',
#  'BT BATOK ST 25',
#  'COMPASSVALE LINK',
#  'KIM TIAN RD',
#  'REDHILL CL',
#  'TAMPINES ST 72',
#  'COMPASSVALE LANE',
#  'JURONG WEST ST 73',
#  'COMPASSVALE CRES',
#  'BUANGKOK CRES',
#  'JLN TENAGA',
#  'TELOK BLANGAH RISE',
#  'JLN TECK WHYE',
#  'BEDOK RESERVOIR VIEW',
#  'WOODLANDS DR 70',
#  'CHAI CHEE AVE',
#  'YISHUN AVE 2',
#  'DEPOT RD',
#  'JOO SENG RD',
#  'JLN MEMBINA',
#  'COMPASSVALE DR',
#  'YISHUN AVE 9',
#  'TAMPINES ST 44',
#  'TAMPINES AVE 8',
#  'KANG CHING RD',
#  'RIVERVALE ST',
#  'GEYLANG EAST AVE 1',
#  'HOUGANG ST 22',
#  'JURONG WEST AVE 5',
#  'BT BATOK ST 24',
#  'TOA PAYOH CTRL',
#  'LOR LEW LIAN',
#  'RIVERVALE WALK',
#  'SERANGOON NTH AVE 3',
#  'TG PAGAR PLAZA',
#  'SIMEI RD',
#  'WELLINGTON CIRCLE',
#  'HOUGANG CTRL',
#  'TOA PAYOH EAST',
#  'BT BATOK ST 51',
#  'BT BATOK WEST AVE 2',
#  'PAYA LEBAR WAY',
#  'PASIR RIS ST 53',
#  'CHOA CHU KANG NTH 5',
#  'KALLANG BAHRU',
#  'ELIAS RD',
#  'ANCHORVALE DR',
#  'WOODLANDS DR 73',
#  'YISHUN AVE 7',
#  'CLEMENTI ST 13',
#  'TAH CHING RD',
#  'PASIR RIS ST 72',
#  'LENGKONG TIGA',
#  'TAMAN HO SWEE',
#  'JURONG WEST ST 74',
#  'WOODLANDS DR 62',
#  'HAVELOCK RD',
#  'WOODLANDS AVE 5',
#  'WOODLANDS DR 52',
#  "ST. GEORGE'S LANE",
#  'JLN RUMAH TINGGI',
#  'JLN RAJAH',
#  'CASSIA CRES',
#  'HOUGANG ST 52',
#  'CHOA CHU KANG DR',
#  'LENGKOK BAHRU',
#  'CHOA CHU KANG AVE 1',
#  'HENDERSON CRES',
#  'PASIR RIS DR 3',
#  'ANG MO KIO AVE 9',
#  'TOWNER RD',
#  'WOODLANDS DR 40',
#  'SEMBAWANG CRES',
#  'BEDOK NTH ST 4',
#  'BISHAN ST 11',
#  'DOVER RD',
#  'PUNGGOL WAY',
#  'PASIR RIS ST 13',
#  "C'WEALTH AVE WEST",
#  'POTONG PASIR AVE 3',
#  'HOUGANG ST 21',
#  'SIN MING RD',
#  'CHOA CHU KANG ST 53',
#  'SERANGOON AVE 1',
#  'TAMPINES CTRL 7',
#  'YISHUN ST 51',
#  'SENGKANG WEST WAY',
#  'CHAI CHEE DR',
#  'LOMPANG RD',
#  'HOUGANG ST 92',
#  'HOUGANG ST 11',
#  'KIM KEAT LINK',
#  'UPP SERANGOON CRES',
#  'MARSILING RD',
#  'WOODLANDS DR 42',
#  'CANTONMENT RD',
#  'BOON KENG RD',
#  'CANTONMENT CL',
#  'MARSILING CRES',
#  'SUMANG WALK',
#  'ANG MO KIO ST 52',
#  'UPP CROSS ST',
#  'PINE CL',
#  'CLEMENTI AVE 6',
#  'DAWSON RD',
#  'JLN DAMAI',
#  'MONTREAL DR',
#  'BEACH RD',
#  'CASHEW RD',
#  'CORPORATION DR',
#  'JURONG WEST ST 25',
#  'CHOA CHU KANG ST 64',
#  'JLN TENTERAM',
#  'WOODLANDS DR 44',
#  'FERNVALE LANE',
#  'BOON TIONG RD',
#  'SIMEI ST 2',
#  'SERANGOON NTH AVE 2',
#  'SUMANG LANE',
#  'EVERTON PK',
#  'REDHILL RD',
#  'PUNGGOL RD',
#  'PIPIT RD',
#  "QUEEN'S CL",
#  'YUNG KUANG RD',
#  'JURONG WEST ST 24',
#  'LOR LIMAU',
#  'EUNOS RD 5',
#  'GHIM MOH LINK',
#  "QUEEN'S RD",
#  'KEAT HONG CL',
#  'JLN BT HO SWEE',
#  'JLN KLINIK',
#  'SERANGOON CTRL DR',
#  'CANBERRA ST',
#  'YUNG PING RD',
#  'LOR 6 TOA PAYOH',
#  'SAUJANA RD',
#  'SELEGIE RD',
#  'YUNG AN RD',
#  'LOR 1A TOA PAYOH',
#  'CHOA CHU KANG ST 54',
#  'JELEBU RD',
#  'WOODLANDS DR 53',
#  'ANG MO KIO ST 32',
#  'LOR 3 TOA PAYOH',
#  'SPOTTISWOODE PK RD',
#  'ANCHORVALE CRES',
#  'WOODLANDS AVE 3',
#  'DELTA AVE',
#  'WOODLANDS ST 11',
#  'JURONG WEST AVE 3',
#  'COMPASSVALE BOW',
#  'UPP ALJUNIED LANE',
#  'BEO CRES',
#  'DAKOTA CRES',
#  'TAMPINES AVE 7',
#  'WOODLANDS DR 72',
#  'SIMEI ST 5',
#  'SENGKANG CTRL',
#  'WHAMPOA RD',
#  'VEERASAMY RD',
#  'MACPHERSON LANE',
#  'TELOK BLANGAH WAY',
#  'DORSET RD',
#  'YISHUN ST 31',
#  'ANCHORVALE LANE',
#  'HOY FATT RD',
#  'HILLVIEW AVE',
#  'FARRER PK RD',
#  'WHAMPOA WEST',
#  'CRAWFORD LANE',
#  'YUNG SHENG RD',
#  'CHOA CHU KANG AVE 7',
#  'TELOK BLANGAH ST 31',
#  'CAMBRIDGE RD',
#  'CHOA CHU KANG LOOP',
#  'KIM TIAN PL',
#  'JLN KUKOH',
#  'DOVER CL EAST',
#  'RACE COURSE RD',
#  'ROWELL RD',
#  'BUANGKOK LINK',
#  'GEYLANG SERAI',
#  'SEMBAWANG VISTA',
#  'ANG MO KIO ST 31',
#  'BT MERAH CTRL',
#  'BT BATOK ST 22',
#  'UPP SERANGOON RD',
#  'SIMS PL',
#  'ZION RD',
#  'JURONG WEST ST 75',
#  'BUFFALO RD',
#  'POTONG PASIR AVE 2',
#  'YUAN CHING RD',
#  'SENGKANG EAST AVE',
#  'HENDERSON RD',
#  'WOODLANDS DR 71',
#  'BEDOK CTRL',
#  'PUNGGOL EAST',
#  'NTH BRIDGE RD',
#  'MONTREAL LINK',
#  'KELANTAN RD',
#  'BT BATOK WEST AVE 7',
#  'GLOUCESTER RD',
#  'SENGKANG EAST RD',
#  "C'WEALTH AVE",
#  'WOODLANDS AVE 9',
#  'TAMPINES CTRL 1',
#  'YUNG HO RD',
#  "KING GEORGE'S AVE",
#  'YUNG LOH RD',
#  'KENT RD',
#  'ROCHOR RD',
#  'HOUGANG ST 31',
#  'QUEEN ST',
#  'INDUS RD',
#  'UPP SERANGOON VIEW',
#  'YISHUN CTRL 1',
#  'CLARENCE LANE',
#  'ANG MO KIO AVE 2',
#  'WATERLOO ST',
#  'YISHUN ST 20',
#  'BRIGHT HILL DR',
#  'JURONG WEST ST 62',
#  'GEYLANG EAST CTRL',
#  'PUNGGOL FIELD WALK',
#  'CANBERRA CRES',
#  'FERNVALE ST',
#  'BUANGKOK GREEN',
#  'CLEMENTI ST 14',
#  'YISHUN AVE 1',
#  'QUEENSWAY',
#  'ANCHORVALE ST',
#  'PASIR RIS ST 41',
#  'WOODLANDS RISE',
#  'CHOA CHU KANG NTH 7',
#  'SENGKANG WEST AVE',
#  'TAMPINES CTRL 8',
#  'YISHUN ST 41',
#  'SENJA LINK',
#  'SIMS AVE',
#  'SUMANG LINK',
#  'KG ARANG RD',
#  'OLD AIRPORT RD',
#  'JOO CHIAT RD',
#  'BT BATOK WEST AVE 9',
#  'CANBERRA LINK',
#  'KLANG LANE',
#  'SHORT ST',
#  'WOODLANDS CTR RD',
#  'TAO CHING RD',
#  'EMPRESS RD',
#  'JURONG WEST ST 72',
#  'KEAT HONG LINK',
#  'SILAT AVE',
#  'BEDOK RESERVOIR CRES',
#  'SAGO LANE',
#  'CANBERRA WALK',
#  'REDHILL LANE',
#  'JLN PASAR BARU',
#  'ANG MO KIO ST 21',
#  'JLN DUA',
#  'FARRER RD',
#  "JLN MA'MOR",
#  'SMITH ST',
#  'SIMEI LANE',
#  'ALJUNIED RD',
#  'AH HOOD RD',
#  'TIONG BAHRU RD',
#  'BAIN ST',
#  'JLN DUSUN',
#  'CHANGI VILLAGE RD',
#  'JLN TIGA',
#  'OWEN RD',
#  'JELLICOE RD',
#  'LOR 3 GEYLANG',
#  'LIM LIAK ST',
#  'TAMPINES ST 61',
#  'TAMPINES ST 86',
#  'JLN KAYU',
#  'MOH GUAN TER',
#  'ANG MO KIO ST 44',
#  'CHANDER RD',
#  'TAMPINES AVE 1',
#  'OUTRAM PK',
#  'FRENCH RD',
#  'NEW MKT RD',
#  'ANG MO KIO ST 51',
#  'LOWER DELTA RD',
#  'WHAMPOA STH',
#  'ANG MO KIO ST 11',
#  'TESSENSOHN RD',
#  'EAST COAST RD',
#  'MOULMEIN RD',
#  'NILE RD',
#  'MARGARET DR',
#  'KG KAYU RD',
#  'JURONG WEST CTRL 3',
#  'BT BATOK EAST AVE 6',
#  'CHIN SWEE RD',
#  'KIM CHENG ST',
#  'YISHUN ST 43',
#  'JURONG WEST ST 51',
#  'JLN BERSEH',
#  'SELETAR WEST FARMWAY 6',
#  'TECK WHYE CRES',
#  'LIM CHU KANG RD',
#  'BUANGKOK STH FARMWAY 1',
#  'KRETA AYER RD',
#  'ALEXANDRA RD',
#  'KG BAHRU HILL',
#  'HU CHING RD',
#  'KIM PONG RD',
#  'CLEMENTI ST 12',
#  'CLEMENTI ST 11',
#  'ANG MO KIO ST 61',
#  'HOUGANG ST 32',
#  'BT MERAH LANE 1',
#  'SEMBAWANG RD',
#  'SENG POH RD',
#  'JLN MEMBINA BARAT',
#  'SEMBAWANG WAY',
#  'GEYLANG EAST AVE 2',
#  'OUTRAM HILL',
#  'BIDADARI PK DR',
#  'SENGKANG WEST RD',
#  'MARINE PARADE CTRL',
#  'TAMPINES NTH DR 1',
#  'CANBERRA VIEW',
#  'ALJUNIED AVE 2']

# %%
df['street_name'] = df['street_name'].replace(unique_once_list, 'Others')

# %%
sorted(df['street_name'].unique())
# Out:
# ['ANG MO KIO AVE 1',
#  'ANG MO KIO AVE 10',
#  'ANG MO KIO AVE 3',
#  'ANG MO KIO AVE 4',
#  'ANG MO KIO AVE 5',
#  'BEDOK NTH RD',
#  'BEDOK NTH ST 3',
#  'BEDOK RESERVOIR RD',
#  'BT BATOK WEST AVE 6',
#  'CIRCUIT RD',
#  'CLEMENTI AVE 4',
#  'HOUGANG AVE 8',
#  'JURONG EAST ST 21',
#  'JURONG WEST ST 42',
#  'LOR 1 TOA PAYOH',
#  'MARSILING DR',
#  'Others',
#  'SIMEI ST 1',
#  'TAMPINES ST 21',
#  'TAMPINES ST 22',
#  'YISHUN RING RD']

# %%
df['street_name'].value_counts()
# Out:
# street_name
# Others                 776706
# YISHUN RING RD          17742
# BEDOK RESERVOIR RD      14834
# ANG MO KIO AVE 10       13913
# ANG MO KIO AVE 3        12240
# HOUGANG AVE 8            9419
# TAMPINES ST 21           8350
# BEDOK NTH ST 3           7627
# BEDOK NTH RD             7526
# ANG MO KIO AVE 4         7276
# MARSILING DR             6698
# JURONG WEST ST 42        6639
# ANG MO KIO AVE 5         6469
# LOR 1 TOA PAYOH          5583
# BT BATOK WEST AVE 6      5563
# SIMEI ST 1               5561
# CIRCUIT RD               5431
# JURONG EAST ST 21        5370
# CLEMENTI AVE 4           5118
# ANG MO KIO AVE 1         5115
# TAMPINES ST 22           5089
# Name: count, dtype: int64

# %%
df['floor_area_sq_ft'] = (df['floor_area_sqm'] * 10.7639).astype(int)

# %%
df['floor_area_sq_ft'].value_counts()
# Out:
# floor_area_sq_ft
# 721     70033
# 1119    47549
# 731     40726
# 904     36402
# 990     31291
#         ...
# 1411        1
# 3304        1
# 1640        1
# 752         1
# 977         1
# Name: count, Length: 214, dtype: int64

# %%
df['flat_model'].value_counts()
# Out:
# flat_model
# Model A                   199087
# Improved                  170870
# New Generation            111376
# NEW GENERATION             78898
# IMPROVED                   73589
# MODEL A                    70381
# Premium Apartment          47977
# Simplified                 34704
# Apartment                  25946
# Standard                   25425
# SIMPLIFIED                 23258
# Maisonette                 17735
# STANDARD                   17375
# MAISONETTE                 12215
# Model A2                   10275
# APARTMENT                   9901
# DBSS                        3426
# Adjoined flat               1270
# Model A-Maisonette          1111
# MODEL A-MAISONETTE           982
# Terrace                      450
# Type S1                      447
# MULTI GENERATION             279
# Multi Generation             265
# TERRACE                      247
# Type S2                      223
# 2-room                       157
# Premium Apartment Loft       114
# Premium Maisonette            86
# Improved-Maisonette           84
# 3Gen                          45
# IMPROVED-MAISONETTE           44
# 2-ROOM                        21
# PREMIUM APARTMENT              6
# Name: count, dtype: int64

# %%
df['flat_model']=df['flat_model'].replace({'IMPROVED': 'Improved'})
df['flat_model']=df['flat_model'].replace({'NEW GENERATION': 'New Generation'})
df['flat_model']=df['flat_model'].replace({'MODEL A': 'Model A'})
df['flat_model']=df['flat_model'].replace({'PREMIUM APARTMENT': 'Premium Apartment'})
df['flat_model']=df['flat_model'].replace({'SIMPLIFIED': 'Simplified'})
df['flat_model']=df['flat_model'].replace({'APARTMENT': 'Apartment'})
df['flat_model']=df['flat_model'].replace({'STANDARD': 'Standard'})
df['flat_model']=df['flat_model'].replace({'MAISONETTE': 'Maisonette'})
df['flat_model']=df['flat_model'].replace({'MODEL A-MAISONETTE': 'Model A-Maisonette'})
df['flat_model']=df['flat_model'].replace({'TERRACE': 'Terrace'})
df['flat_model']=df['flat_model'].replace({'MULTI GENERATION': 'Multi Generation'})
df['flat_model']=df['flat_model'].replace({'2-ROOM': '2-room'})
df['flat_model']=df['flat_model'].replace({'IMPROVED-MAISONETTE': 'Improved-Maisonette'})

# %%
df['flat_model'].value_counts()
# Out:
# flat_model
# Model A                   269468
# Improved                  244459
# New Generation            190274
# Simplified                 57962
# Premium Apartment          47983
# Standard                   42800
# Apartment                  35847
# Maisonette                 29950
# Model A2                   10275
# DBSS                        3426
# Model A-Maisonette          2093
# Adjoined flat               1270
# Terrace                      697
# Multi Generation             544
# Type S1                      447
# Type S2                      223
# 2-room                       178
# Improved-Maisonette          128
# Premium Apartment Loft       114
# Premium Maisonette            86
# 3Gen                          45
# Name: count, dtype: int64

# %%
df['flat_model']=df['flat_model'].replace({'Terrace': 'Others'})
df['flat_model']=df['flat_model'].replace({'Multi Generation': 'Others'})
df['flat_model']=df['flat_model'].replace({'Type S1': 'Others'})
df['flat_model']=df['flat_model'].replace({'Type S2': 'Others'})
df['flat_model']=df['flat_model'].replace({'2-room': 'Others'})
df['flat_model']=df['flat_model'].replace({'Improved-Maisonette': 'Others'})
df['flat_model']=df['flat_model'].replace({'Premium Apartment Loft': 'Others'})
df['flat_model']=df['flat_model'].replace({'Premium Maisonette': 'Others'})
df['flat_model']=df['flat_model'].replace({'3Gen': 'Others'})

# %%
sorted(df['flat_model'].unique())
# Out:
# ['Adjoined flat',
#  'Apartment',
#  'DBSS',
#  'Improved',
#  'Maisonette',
#  'Model A',
#  'Model A-Maisonette',
#  'Model A2',
#  'New Generation',
#  'Others',
#  'Premium Apartment',
#  'Simplified',
#  'Standard']

# %%
df['lease_commence_date'].value_counts()
# Out:
# lease_commence_date
# 1985    88056
# 1984    63940
# 1988    51112
# 1987    43162
# 1978    41605
# 1986    38912
# 1989    32496
# 1980    32250
# 1997    31275
# 1979    31201
# 1993    28427
# 1996    28352
# 1998    25995
# 1983    23248
# 1976    21728
# 1999    21207
# 1981    21098
# 1977    20887
# 1992    20400
# 2001    19819
# 1995    19168
# 2000    18680
# 1975    17522
# 2003    16052
# 1974    14691
# 1982    13428
# 2002    12810
# 1970    11536
# 2015    10627
# 1990     9365
# 1973     8666
# 2004     8602
# 1969     8416
# 1971     7921
# 2016     6650
# 1994     6616
# 1967     6241
# 2018     6192
# 1972     5877
# 2013     5752
# 2017     5708
# 2012     5156
# 2005     4125
# 2014     3942
# 2006     3282
# 2011     2757
# 2019     2716
# 2008     2210
# 1968     1881
# 2009     1844
# 2010     1408
# 1991     1260
# 2007     1016
# 2020      948
# 1966       34
# Name: count, dtype: int64

# %%
df['resale_price'].value_counts()
# Out:
# resale_price
# 300000.0    6941
# 350000.0    6897
# 280000.0    6559
# 320000.0    6548
# 380000.0    6365
#             ...
# 238998.0       1
# 158598.0       1
# 240570.0       1
# 242428.0       1
# 950500.0       1
# Name: count, Length: 9692, dtype: int64

# %%
df['remaining_lease'].value_counts()
# Out:
# remaining_lease
# 68                    2328
# 67                    1857
# 94 years 10 months    1704
# 94 years 09 months    1704
# 94 years 11 months    1673
#                       ...
# 97 years 01 month        1
# 48                       1
# 93 years 0 months        1
# 95 years 0 months        1
# 66 years 0 months        1
# Name: count, Length: 729, dtype: int64

# %%
df['remaining_lease'].fillna(99-(df['year']-df['lease_commence_date']),inplace=True)

# %%
df['remaining_lease'] = pd.to_numeric(df['remaining_lease'], errors='coerce')

# %%
df['age_of_property']= df['year']-df['lease_commence_date']

# %%
df['age_of_property'].value_counts()
# Out:
# age_of_property
#  5     51669
#  4     50421
#  6     38727
#  10    34466
#  13    34409
#        ...
#  57      104
#  0       100
# -1        47
# -2         4
#  58        2
# Name: count, Length: 61, dtype: int64

# %%
df= df[df['age_of_property'] > 0]

# %%
df['age_of_property'].value_counts()
# Out:
# age_of_property
# 5     51669
# 4     50421
# 6     38727
# 10    34466
# 13    34409
# 14    34310
# 11    34210
# 12    33564
# 9     33124
# 7     32571
# 15    31436
# 8     31420
# 16    29941
# 17    29186
# 18    28682
# 20    28342
# 19    28118
# 21    27515
# 22    25396
# 23    24303
# 24    22494
# 25    21542
# 26    19593
# 27    18064
# 28    16721
# 29    15454
# 30    14602
# 31    14056
# 32    13025
# 33    12447
# 34    12112
# 35    11298
# 36    10620
# 37     9402
# 3      9175
# 38     8593
# 39     7554
# 40     6155
# 41     5039
# 42     4591
# 43     4359
# 44     3780
# 45     3160
# 46     2647
# 47     2049
# 48     1690
# 49     1281
# 50     1061
# 51      780
# 52      728
# 53      585
# 2       533
# 54      446
# 55      230
# 1       211
# 56      125
# 57      104
# 58        2
# Name: count, dtype: int64

# %%
df.dtypes
# Out:
# month                    int64
# town                    object
# flat_type               object
# block                   object
# street_name             object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# remaining_lease        float64
# year                     int64
# storey_start             int64
# storey_end               int64
# floor_area_sq_ft         int32
# age_of_property          int64
# dtype: object

# %%
mask= df['remaining_lease']>99
df=df[~mask]

# %%
df.dtypes
# Out:
# month                    int64
# town                    object
# flat_type               object
# block                   object
# street_name             object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# remaining_lease        float64
# year                     int64
# storey_start             int64
# storey_end               int64
# floor_area_sq_ft         int32
# age_of_property          int64
# dtype: object

# %%
df.shape
# Out:
# (938118, 15)

# %%
df['year'].value_counts()
# Out:
# year
# 1999    57782
# 1998    51095
# 2001    38055
# 2002    36098
# 1996    34886
# 2000    34862
# 2010    34853
# 1997    31759
# 2009    30482
# 2005    30023
# 2004    29110
# 2021    29087
# 2003    29003
# 2006    27419
# 2008    27262
# 1995    27250
# 2007    26982
# 2022    26720
# 1994    26348
# 2023    25755
# 2020    23333
# 2012    23198
# 2024    22915
# 2011    22280
# 2019    22186
# 2018    21561
# 2017    20509
# 2016    19373
# 1993    18104
# 2015    17780
# 2013    16097
# 2014    16096
# 1992    14496
# 1991    12854
# 1990    12505
# Name: count, dtype: int64

# %%
df['year'].unique()
# Out:
# array([1990, 1991, 1992, 1993, 1994, 1995, 1996, 1997, 1998, 1999, 2000,
#        2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010, 2011,
#        2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020, 2021, 2022,
#        2023, 2024], dtype=int64)

# %%
df['street_name'].unique()
# Out:
# array(['ANG MO KIO AVE 1', 'ANG MO KIO AVE 3', 'ANG MO KIO AVE 4',
#        'ANG MO KIO AVE 10', 'ANG MO KIO AVE 5', 'Others',
#        'BEDOK RESERVOIR RD', 'BEDOK NTH ST 3', 'BEDOK NTH RD',
#        'BT BATOK WEST AVE 6', 'CLEMENTI AVE 4', 'CIRCUIT RD',
#        'JURONG EAST ST 21', 'JURONG WEST ST 42', 'TAMPINES ST 21',
#        'TAMPINES ST 22', 'LOR 1 TOA PAYOH', 'MARSILING DR',
#        'YISHUN RING RD', 'HOUGANG AVE 8', 'SIMEI ST 1'], dtype=object)

# %%
df['storey_start'].value_counts()
# Out:
# storey_start
# 4     235110
# 7     212434
# 1     191116
# 10    180847
# 13     63113
# 16     24940
# 19     11669
# 22      7564
# 25      3536
# 6       2474
# 28      1707
# 11      1259
# 31       672
# 34       618
# 37       531
# 40       253
# 21        92
# 43        66
# 46        53
# 26        39
# 49        18
# 36         7
# Name: count, dtype: int64

# %%
df['storey_end'].value_counts()
# Out:
# storey_end
# 6     235110
# 9     212434
# 3     188416
# 12    180847
# 15     64372
# 18     24675
# 21     11669
# 24      7564
# 27      3536
# 5       2700
# 10      2474
# 30      1746
# 33       670
# 36       618
# 39       531
# 20       265
# 42       253
# 25        92
# 45        66
# 48        53
# 51        18
# 40         7
# 35         2
# Name: count, dtype: int64

# %%
df.isnull().sum()
# Out:
# month                       0
# town                        0
# flat_type                   0
# block                       0
# street_name                 0
# floor_area_sqm              0
# flat_model                  0
# lease_commence_date         0
# resale_price                0
# remaining_lease        192066
# year                        0
# storey_start                0
# storey_end                  0
# floor_area_sq_ft            0
# age_of_property             0
# dtype: int64

# %%
df.shape
# Out:
# (938118, 15)

# %%
df['remaining_lease'].median()
# Out:
# 84.0

# %%
df['remaining_lease'].fillna(84.0, inplace=True)

# %%
df['remaining_lease'] = df['remaining_lease'].astype(int)

# %%
df.isnull().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# remaining_lease        0
# year                   0
# storey_start           0
# storey_end             0
# floor_area_sq_ft       0
# age_of_property        0
# dtype: int64

# %%
df.shape
# Out:
# (938118, 15)

# %%
df['Floor_median'] = df[['storey_start', 'storey_end']].median(axis=1)
df['Floor_median'] = df['Floor_median'].astype(int)

# %%
df['Floor_median'].value_counts()
# Out:
# Floor_median
# 5     235110
# 8     214908
# 2     188416
# 11    180847
# 14     63113
# 17     24675
# 20     11669
# 23      7656
# 26      3536
# 3       2700
# 29      1707
# 13      1259
# 32       670
# 35       618
# 38       538
# 18       265
# 41       253
# 44        66
# 47        53
# 28        39
# 50        18
# 33         2
# Name: count, dtype: int64

# %%
df.head()
# Out:
#    month        town flat_type block       street_name  floor_area_sqm  \
# 0      1  ANG MO KIO    Others   309  ANG MO KIO AVE 1            31.0
# 1      1  ANG MO KIO    Others   309  ANG MO KIO AVE 1            31.0
# 2      1  ANG MO KIO    Others   309  ANG MO KIO AVE 1            31.0
# 3      1  ANG MO KIO    Others   309  ANG MO KIO AVE 1            31.0
# 4      1  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1            73.0
#
#        flat_model  lease_commence_date  resale_price  remaining_lease  year  \
# 0        Improved                 1977        9000.0               86  1990
# 1        Improved                 1977        6000.0               86  1990
# 2        Improved                 1977        8000.0               86  1990
# 3        Improved                 1977        6000.0               86  1990
# 4  New Generation                 1976       47200.0               85  1990
#
#    storey_start  storey_end  floor_area_sq_ft  age_of_property  Floor_median
# 0            10          12               333               13            11
# 1             4           6               333               13             5
# 2            10          12               333               13            11
# 3             7           9               333               13             8
# 4             4           6               785               14             5

# %%
df['block'].value_counts()
# Out:
# block
# 2       4620
# 1       4079
# 110     3442
# 101     3429
# 4       3368
#         ...
# 457B       1
# 458B       1
# 458A       1
# 610C       1
# 610A       1
# Name: count, Length: 2719, dtype: int64

# %%
v_c_b = df['block'].value_counts()
freq1 = (v_c_b[v_c_b<1000]).index

unique_list = list(freq1)
unique_list
# Out:
# ['601',
#  '515',
#  '75',
#  '635',
#  '603',
#  '178',
#  '437',
#  '83',
#  '224',
#  '96',
#  '702',
#  '639',
#  '348',
#  '98',
#  '606',
#  '433',
#  '337',
#  '56',
#  '545',
#  '621',
#  '429',
#  '637',
#  '97',
#  '271',
#  '265',
#  '547',
#  '255',
#  '61',
#  '604',
#  '259',
#  '180',
#  '526',
#  '95',
#  '445',
#  '715',
#  '450',
#  '162',
#  '525',
#  '463',
#  '335',
#  '549',
#  '529',
#  '269',
#  '81',
#  '318',
#  '629',
#  '363',
#  '352',
#  '48',
#  '283',
#  '349',
#  '41',
#  '711',
#  '195',
#  '717',
#  '617',
#  '608',
#  '615',
#  '93',
#  '174',
#  '444',
#  '256',
#  '91',
#  '456',
#  '467',
#  '728',
#  '725',
#  '713',
#  '436',
#  '519',
#  '49',
#  '619',
#  '175',
#  '539',
#  '708',
#  '458',
#  '270',
#  '634',
#  '640',
#  '177',
#  '644',
#  '642',
#  '538',
#  '705',
#  '274',
#  '623',
#  '527',
#  '181',
#  '443',
#  '182',
#  '430',
#  '448',
#  '449',
#  '718',
#  '315',
#  '76',
#  '340',
#  '350',
#  '646',
#  '457',
#  '74',
#  '434',
#  '552',
#  '465',
#  '86',
#  '461',
#  '522',
#  '546',
#  '462',
#  '531',
#  '262',
#  '625',
#  '69',
#  '266',
#  '548',
#  '630',
#  '722',
#  '367',
#  '100',
#  '724',
#  '729',
#  '275',
#  '68',
#  '39',
#  '530',
#  '551',
#  '636',
#  '442',
#  '553',
#  '614',
#  '622',
#  '543',
#  '338',
#  '459',
#  '474',
#  '261',
#  '260',
#  '624',
#  '470',
#  '616',
#  '439',
#  '721',
#  '632',
#  '432',
#  '431',
#  '455',
#  '720',
#  '774',
#  '556',
#  '618',
#  '353',
#  '473',
#  '273',
#  '723',
#  '446',
#  '466',
#  '557',
#  '484',
#  '99',
#  '258',
#  '67',
#  '72',
#  '649',
#  '365',
#  '454',
#  '289',
#  '476',
#  '469',
#  '183',
#  '471',
#  '288',
#  '472',
#  '357',
#  '517',
#  '280',
#  '719',
#  '287',
#  '87',
#  '739',
#  '662',
#  '276',
#  '558',
#  '286',
#  '364',
#  '645',
#  '804',
#  '853',
#  '447',
#  '347',
#  '451',
#  '176',
#  '359',
#  '460',
#  '277',
#  '453',
#  '736',
#  '475',
#  '355',
#  '361',
#  '441',
#  '362',
#  '660',
#  '73',
#  '638',
#  '641',
#  '628',
#  '268',
#  '559',
#  '481',
#  '742',
#  '544',
#  '730',
#  '770',
#  '179',
#  '452',
#  '284',
#  '840',
#  '762',
#  '366',
#  '438',
#  '771',
#  '360',
#  '661',
#  '468',
#  '766',
#  '851',
#  '278',
#  '731',
#  '483',
#  '756',
#  '371',
#  '726',
#  '760',
#  '854',
#  '740',
#  '759',
#  '741',
#  '88',
#  '571',
#  '79',
#  '658',
#  '773',
#  '89',
#  '560',
#  '90',
#  '293',
#  '575',
#  '751',
#  '755',
#  '734',
#  '368',
#  '842',
#  '285',
#  '344',
#  '486',
#  '648',
#  '477',
#  '78',
#  '803',
#  '855',
#  '570',
#  '735',
#  '480',
#  '194',
#  '752',
#  '647',
#  '738',
#  '184',
#  '838',
#  '852',
#  '652',
#  '655',
#  '765',
#  '754',
#  '758',
#  '565',
#  '358',
#  '830',
#  '836',
#  '769',
#  '94',
#  '839',
#  '564',
#  '816',
#  '657',
#  '805',
#  '764',
#  '193',
#  '651',
#  '868',
#  '825',
#  '757',
#  '727',
#  '843',
#  '733',
#  '85',
#  '342',
#  '810',
#  '745',
#  '772',
#  '864',
#  '291',
#  '737',
#  '279',
#  '761',
#  '92',
#  '749',
#  '555',
#  '464',
#  '850',
#  '485',
#  '746',
#  '929',
#  '879',
#  '925',
#  '845',
#  '84',
#  '832',
#  '374',
#  '833',
#  '846',
#  '653',
#  '191',
#  '910',
#  '841',
#  '806',
#  '862',
#  '750',
#  '297',
#  '763',
#  '775',
#  '909',
#  '824',
#  '650',
#  '356',
#  '808',
#  '861',
#  '875',
#  '71',
#  '294',
#  '665',
#  '867',
#  '577',
#  '576',
#  '669',
#  '296',
#  '561',
#  '809',
#  '281',
#  '663',
#  '865',
#  '190',
#  '732',
#  '199',
#  '369',
#  '744',
#  '866',
#  '776',
#  '478',
#  '812',
#  '858',
#  '370',
#  '767',
#  '873',
#  '807',
#  '666',
#  '874',
#  '667',
#  '295',
#  '802',
#  '487',
#  '790',
#  '298',
#  '394',
#  '188',
#  '914',
#  '578',
#  '911',
#  '936',
#  '926',
#  '916',
#  '860',
#  '282',
#  '877',
#  '753',
#  '395',
#  '859',
#  '813',
#  '821',
#  '856',
#  '915',
#  '586',
#  '863',
#  '922',
#  '837',
#  '814',
#  '70',
#  '393',
#  '829',
#  '820',
#  '834',
#  '747',
#  '778',
#  '748',
#  '848',
#  '930',
#  '743',
#  '835',
#  '801',
#  '585',
#  '388',
#  '768',
#  '831',
#  '656',
#  '847',
#  '482',
#  '562',
#  '573',
#  '391',
#  '668',
#  '826',
#  '871',
#  '168A',
#  '817',
#  '192',
#  '80',
#  '928',
#  '372',
#  '677',
#  '939',
#  '572',
#  '932',
#  '390',
#  '671',
#  '902',
#  '479',
#  '815',
#  '878',
#  '389',
#  '818',
#  '684A',
#  '290',
#  '659',
#  '681',
#  '686B',
#  '940',
#  '819',
#  '811',
#  '872',
#  '568',
#  '491',
#  '686A',
#  '308A',
#  '921',
#  '673',
#  '569',
#  '784',
#  '678',
#  '942',
#  '587',
#  '844',
#  '663A',
#  '386',
#  '907',
#  '584',
#  '788',
#  '680',
#  '897A',
#  '200',
#  '567',
#  '492',
#  '899A',
#  '693',
#  '880',
#  '689',
#  '196',
#  '912',
#  '654',
#  '688',
#  '664',
#  '392',
#  '924',
#  '197',
#  '917',
#  '684C',
#  '944',
#  '288C',
#  '941',
#  '896A',
#  '827',
#  '670',
#  '876',
#  '310B',
#  '695',
#  '373',
#  '672A',
#  '792',
#  '690',
#  '934',
#  '943',
#  '857',
#  '683A',
#  '870',
#  '1A',
#  '189',
#  '201D',
#  '673A',
#  '375',
#  '684B',
#  '945',
#  '385',
#  '795',
#  '686C',
#  '777',
#  '881',
#  '828',
#  '894A',
#  '903',
#  '892A',
#  '791',
#  '489',
#  '308B',
#  '796',
#  '315A',
#  '292',
#  '566',
#  '935',
#  '682',
#  '104A',
#  '933',
#  '664A',
#  '288A',
#  '781',
#  '794',
#  '913',
#  '684',
#  '308C',
#  '2A',
#  '783',
#  '946',
#  '273B',
#  '563',
#  '399',
#  '690D',
#  '938',
#  '671A',
#  '384',
#  '119B',
#  '672',
#  '580',
#  '683C',
#  '685B',
#  '685C',
#  '898A',
#  '377',
#  '785',
#  '696',
#  '275A',
#  '789',
#  '273D',
#  '397',
#  '682C',
#  '288B',
#  '490',
#  '322A',
#  '687C',
#  '387',
#  '379',
#  '14A',
#  '931',
#  '685',
#  '579',
#  '895A',
#  '687B',
#  '310A',
#  '849',
#  '574',
#  '316A',
#  '882',
#  '683B',
#  '288D',
#  '488',
#  '27A',
#  '920',
#  '688A',
#  '381',
#  '299',
#  '670A',
#  '674',
#  '268C',
#  '679',
#  '10B',
#  '273A',
#  '688B',
#  '450A',
#  '311B',
#  '104B',
#  '273C',
#  '923',
#  '269B',
#  '291D',
#  '489A',
#  '383',
#  '823',
#  '786D',
#  '296A',
#  '315B',
#  '469B',
#  '271A',
#  '684D',
#  '225A',
#  '376',
#  '798',
#  '296B',
#  '289A',
#  '335A',
#  '657B',
#  '289B',
#  '291A',
#  '500',
#  '489C',
#  '85A',
#  '290B',
#  '272B',
#  '787C',
#  '884',
#  '786',
#  '297A',
#  '469A',
#  '3A',
#  '687A',
#  '485B',
#  '311A',
#  '919',
#  '681C',
#  '869',
#  '787D',
#  '271B',
#  '690A',
#  '311C',
#  '688C',
#  '23A',
#  '290A',
#  '312B',
#  '450C',
#  '908',
#  '686',
#  '5A',
#  '779',
#  '689B',
#  '906',
#  '85B',
#  '467A',
#  '271C',
#  '85C',
#  '787',
#  '904',
#  '119C',
#  '692',
#  '126A',
#  '883',
#  '303B',
#  '272C',
#  '683',
#  '786B',
#  '786C',
#  '976',
#  '126C',
#  '937',
#  '694',
#  '671B',
#  '628B',
#  '691A',
#  '506A',
#  '950',
#  '467B',
#  '894',
#  '692B',
#  '124B',
#  '889A',
#  '675',
#  '272D',
#  '291C',
#  '685A',
#  '121A',
#  '299A',
#  '306C',
#  '296C',
#  '309A',
#  '842B',
#  '297B',
#  '691',
#  '673C',
#  '885',
#  '291B',
#  '2C',
#  '312A',
#  '691B',
#  '120A',
#  '487B',
#  '682A',
#  '203A',
#  '891A',
#  '138C',
#  '690C',
#  '198',
#  '4B',
#  '977',
#  '489B',
#  '183C',
#  '201B',
#  '889',
#  '204A',
#  '116A',
#  '117A',
#  '292B',
#  '335B',
#  '289D',
#  '953',
#  '272A',
#  '221A',
#  '895C',
#  '697',
#  '897B',
#  '822',
#  '613B',
#  '676',
#  '588C',
#  '918',
#  '268B',
#  '927',
#  '690B',
#  '485A',
#  '268A',
#  '898',
#  '407A',
#  '893A',
#  '668A',
#  '864A',
#  '298A',
#  '797',
#  '674A',
#  '468A',
#  '786E',
#  '502A',
#  '288E',
#  '689A',
#  '269A',
#  '897C',
#  '106A',
#  '289E',
#  '898B',
#  '259C',
#  '180A',
#  '183D',
#  '842G',
#  '303C',
#  '952',
#  '138B',
#  '504D',
#  '287A',
#  '800',
#  '782',
#  '175A',
#  '667A',
#  '672B',
#  '316C',
#  '842H',
#  '275C',
#  '655B',
#  '298B',
#  '138A',
#  '128A',
#  '487C',
#  '290C',
#  '667B',
#  '80A',
#  '131B',
#  '290D',
#  '682B',
#  '663C',
#  '787B',
#  '891B',
#  '663B',
#  '488A',
#  '310C',
#  '965',
#  '676B',
#  '302A',
#  '892B',
#  '664B',
#  '289C',
#  '108C',
#  '219A',
#  '286A',
#  '173A',
#  '103A',
#  '185B',
#  '180B',
#  '286C',
#  '657A',
#  '260A',
#  '201A',
#  '650A',
#  '497H',
#  '339A',
#  '687',
#  '26B',
#  '108B',
#  '899B',
#  '79A',
#  '406C',
#  '39A',
#  '17A',
#  '260B',
#  '117B',
#  '679C',
#  '269C',
#  '274B',
#  '668B',
#  '139A',
#  '207D',
#  '119D',
#  '270A',
#  '407B',
#  '859A',
#  '286B',
#  '588B',
#  '624A',
#  '10A',
#  '291E',
#  '673B',
#  '314B',
#  '203B',
#  '275B',
#  '793',
#  '655A',
#  '668C',
#  '497C',
#  '274A',
#  '120B',
#  '484D',
#  '676A',
#  '895',
#  '23B',
#  '674B',
#  '303A',
#  '121D',
#  '443A',
#  '299B',
#  '681A',
#  '681B',
#  '441B',
#  '217B',
#  '183A',
#  '302B',
#  '339B',
#  '624B',
#  '899',
#  '484A',
#  '79E',
#  '316B',
#  '295A',
#  '888',
#  '582',
#  '504C',
#  '443C',
#  '961',
#  '987C',
#  '635A',
#  '871A',
#  '493D',
#  '305A',
#  '226A',
#  '290G',
#  '443B',
#  '312C',
#  '896C',
#  '306A',
#  '636B',
#  '861A',
#  '583',
#  '979',
#  '101B',
#  '290E',
#  '305D',
#  '588A',
#  '862A',
#  '185C',
#  '313C',
#  '787E',
#  '490A',
#  '202A',
#  '306B',
#  '122A',
#  '172A',
#  '209C',
#  '116B',
#  '430A',
#  '799',
#  '121B',
#  '213A',
#  '261B',
#  '660A',
#  '298D',
#  '274D',
#  '259A',
#  '628A',
#  '666A',
#  '661C',
#  '268D',
#  '275D',
#  '180C',
#  '307C',
#  '101A',
#  '497B',
#  '596C',
#  '107A',
#  '899C',
#  '287B',
#  '267A',
#  '484C',
#  '470A',
#  '289F',
#  '662B',
#  '403D',
#  '313B',
#  '987B',
#  '183B',
#  '496C',
#  '659C',
#  '305B',
#  '8B',
#  '487A',
#  '504B',
#  '488B',
#  '440C',
#  '669B',
#  '315C',
#  '692A',
#  '486A',
#  '486B',
#  '408C',
#  '501A',
#  '432A',
#  '210C',
#  '661A',
#  '894B',
#  '184C',
#  '396',
#  '287C',
#  '166B',
#  '440B',
#  '1C',
#  '201C',
#  '317A',
#  '497G',
#  '894D',
#  '301C',
#  '484B',
#  '293D',
#  '290F',
#  '496D',
#  '887',
#  '1E',
#  '468B',
#  '139B',
#  '110A',
#  '663D',
#  '109A',
#  '208B',
#  '470B',
#  '975',
#  '688F',
#  '128C',
#  '1B',
#  '1G',
#  '496B',
#  '897',
#  '636A',
#  '176D',
#  '188B',
#  '18A',
#  '780',
#  '289G',
#  '436A',
#  '217A',
#  '259B',
#  '496E',
#  '314A',
#  '211D',
#  '2B',
#  '205A',
#  '867A',
#  '271D',
#  '212A',
#  '856C',
#  '874A',
#  '896',
#  '298C',
#  ...]

# %%
df['block'] = df['block'].replace(unique_list, 'Others')

# %%
df['block'].value_counts()
# Out:
# block
# Others    430091
# 2           4620
# 1           4079
# 110         3442
# 101         3429
#            ...
# 246         1013
# 245         1008
# 631         1007
# 46          1006
# 541         1000
# Name: count, Length: 322, dtype: int64

# %%
df.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'floor_area_sqm',
#        'flat_model', 'lease_commence_date', 'resale_price', 'remaining_lease',
#        'year', 'storey_start', 'storey_end', 'floor_area_sq_ft',
#        'age_of_property', 'Floor_median'],
#       dtype='object')

# %%
Categoricaldata = ['town', 'flat_type', 'block', 'street_name', 'flat_model']
Numericaldata = ['month', 'lease_commence_date', 'resale_price', 'remaining_lease', 'year', 'floor_area_sq_ft','Floor_median', 'age_of_property']
new_df = df[Numericaldata]
new_df_c=df[Categoricaldata]
new_df.head()
# Out:
#    month  lease_commence_date  resale_price  remaining_lease  year  \
# 0      1                 1977        9000.0               86  1990
# 1      1                 1977        6000.0               86  1990
# 2      1                 1977        8000.0               86  1990
# 3      1                 1977        6000.0               86  1990
# 4      1                 1976       47200.0               85  1990
#
#    floor_area_sq_ft  Floor_median  age_of_property
# 0               333            11               13
# 1               333             5               13
# 2               333            11               13
# 3               333             8               13
# 4               785             5               14

# %%
new_df_c.head()
# Out:
#          town flat_type block       street_name      flat_model
# 0  ANG MO KIO    Others   309  ANG MO KIO AVE 1        Improved
# 1  ANG MO KIO    Others   309  ANG MO KIO AVE 1        Improved
# 2  ANG MO KIO    Others   309  ANG MO KIO AVE 1        Improved
# 3  ANG MO KIO    Others   309  ANG MO KIO AVE 1        Improved
# 4  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1  New Generation

# %%
# Define the number of columns and rows for the subplot grid
num_cols = 4
num_rows = 2

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15,5))

# Flatten the axes array for easy indexing
axes = axes.flatten()

# Loop through the DataFrame columns and plot
for i, column in enumerate(new_df.columns):
    sns.boxplot(new_df[column], ax=axes[i])  # Replace with desired plot type
    axes[i].set_title(f'Boxplot of {column}')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Define the number of columns and rows for the subplot grid
num_cols = 4
num_rows = 2

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15,10))

# Flatten the axes array for easy indexing
axes = axes.flatten()

# Loop through the DataFrame columns and plot
for i, column in enumerate(new_df.columns):
    sns.distplot(new_df[column], ax=axes[i])  # Replace with desired plot type
    axes[i].set_title(f'Boxplot of {column}')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
# Define the number of columns and rows for the subplot grid
num_cols = 1
num_rows = 5

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15, 10))

# Flatten the axes array for easy indexing
axes = axes.flatten()

# Loop through the DataFrame columns and plot
for i, column in enumerate(new_df_c.columns):
    sns.histplot(new_df_c[column], ax=axes[i], bins=10, kde=True)  # Replace with desired plot type
    axes[i].set_title(f'Histogram of {column}')
    axes[i].tick_params(axis='x', labelsize=8)
axes[i].set_xticklabels(axes[i].get_xticks(), rotation=45, ha='right')

# Adjust layout
plt.tight_layout()

plt.show()

# %% [markdown]
# features = df[[ 'floor_area_sqm', 'lease_commence_date', 'resale_price', 'remaining_lease', 'floor_area_sq_ft','Floor_median', 'age_of_property']]
#
#
#     # Initialize the Isolation Forest model
# iso_forest = IsolationForest(contamination=0.1, random_state=4)
#
# # Fit the model
# iso_forest.fit(features)
#
# # Predict anomalies (-1 for anomalies, 1 for normal points)
# df['anomaly'] = iso_forest.predict(features)
#
#
#
# print(df)

# %% [markdown]
# df = df[df['anomaly'] != -1]
# print(df)

# %%
df.dtypes
# Out:
# month                    int64
# town                    object
# flat_type               object
# block                   object
# street_name             object
# floor_area_sqm         float64
# flat_model              object
# lease_commence_date      int64
# resale_price           float64
# remaining_lease          int32
# year                     int64
# storey_start             int64
# storey_end               int64
# floor_area_sq_ft         int32
# age_of_property          int64
# Floor_median             int32
# dtype: object

# %%
df.isnull().sum()
# Out:
# month                  0
# town                   0
# flat_type              0
# block                  0
# street_name            0
# floor_area_sqm         0
# flat_model             0
# lease_commence_date    0
# resale_price           0
# remaining_lease        0
# year                   0
# storey_start           0
# storey_end             0
# floor_area_sq_ft       0
# age_of_property        0
# Floor_median           0
# dtype: int64

# %%
df.head(55)
# Out:
#     month        town flat_type   block        street_name  floor_area_sqm  \
# 0       1  ANG MO KIO    Others     309   ANG MO KIO AVE 1            31.0
# 1       1  ANG MO KIO    Others     309   ANG MO KIO AVE 1            31.0
# 2       1  ANG MO KIO    Others     309   ANG MO KIO AVE 1            31.0
# 3       1  ANG MO KIO    Others     309   ANG MO KIO AVE 1            31.0
# 4       1  ANG MO KIO    3 ROOM     216   ANG MO KIO AVE 1            73.0
# 5       1  ANG MO KIO    3 ROOM     211   ANG MO KIO AVE 3            67.0
# 6       1  ANG MO KIO    3 ROOM     202   ANG MO KIO AVE 3            67.0
# 7       1  ANG MO KIO    3 ROOM     235   ANG MO KIO AVE 3            67.0
# 8       1  ANG MO KIO    3 ROOM     235   ANG MO KIO AVE 3            67.0
# 9       1  ANG MO KIO    3 ROOM     232   ANG MO KIO AVE 3            67.0
# 10      1  ANG MO KIO    3 ROOM     232   ANG MO KIO AVE 3            67.0
# 11      1  ANG MO KIO    3 ROOM     308   ANG MO KIO AVE 1            82.0
# 12      1  ANG MO KIO    3 ROOM     308   ANG MO KIO AVE 1            67.0
# 13      1  ANG MO KIO    3 ROOM     220   ANG MO KIO AVE 1            67.0
# 14      1  ANG MO KIO    3 ROOM     219   ANG MO KIO AVE 1            82.0
# 15      1  ANG MO KIO    3 ROOM     247   ANG MO KIO AVE 3            82.0
# 16      1  ANG MO KIO    3 ROOM     320   ANG MO KIO AVE 1            73.0
# 17      1  ANG MO KIO    3 ROOM     252   ANG MO KIO AVE 4            67.0
# 18      1  ANG MO KIO    3 ROOM     223   ANG MO KIO AVE 1            67.0
# 19      1  ANG MO KIO    3 ROOM     223   ANG MO KIO AVE 1            67.0
# 20      1  ANG MO KIO    3 ROOM     230   ANG MO KIO AVE 3            82.0
# 21      1  ANG MO KIO    3 ROOM     329   ANG MO KIO AVE 3            73.0
# 22      1  ANG MO KIO    3 ROOM     313   ANG MO KIO AVE 3            73.0
# 23      1  ANG MO KIO    3 ROOM     117   ANG MO KIO AVE 4            74.0
# 24      1  ANG MO KIO    3 ROOM     110   ANG MO KIO AVE 4            67.0
# 25      1  ANG MO KIO    3 ROOM     343   ANG MO KIO AVE 3            73.0
# 26      1  ANG MO KIO    3 ROOM     345   ANG MO KIO AVE 3            73.0
# 27      1  ANG MO KIO    3 ROOM     346   ANG MO KIO AVE 3            73.0
# 28      1  ANG MO KIO    3 ROOM     121   ANG MO KIO AVE 3            67.0
# 29      1  ANG MO KIO    3 ROOM     129   ANG MO KIO AVE 3            73.0
# 30      1  ANG MO KIO    3 ROOM     130   ANG MO KIO AVE 3            88.0
# 31      1  ANG MO KIO    3 ROOM     128   ANG MO KIO AVE 3            67.0
# 32      1  ANG MO KIO    3 ROOM     127   ANG MO KIO AVE 3            67.0
# 33      1  ANG MO KIO    3 ROOM     126   ANG MO KIO AVE 3            82.0
# 34      1  ANG MO KIO    3 ROOM     403  ANG MO KIO AVE 10            67.0
# 35      1  ANG MO KIO    3 ROOM     404  ANG MO KIO AVE 10            67.0
# 36      1  ANG MO KIO    3 ROOM     405  ANG MO KIO AVE 10            67.0
# 37      1  ANG MO KIO    3 ROOM     417  ANG MO KIO AVE 10            89.0
# 38      1  ANG MO KIO    3 ROOM     418  ANG MO KIO AVE 10            74.0
# 39      1  ANG MO KIO    3 ROOM     418  ANG MO KIO AVE 10            74.0
# 40      1  ANG MO KIO    3 ROOM     419  ANG MO KIO AVE 10            74.0
# 41      1  ANG MO KIO    3 ROOM  Others  ANG MO KIO AVE 10            67.0
# 42      1  ANG MO KIO    3 ROOM  Others  ANG MO KIO AVE 10            67.0
# 43      1  ANG MO KIO    3 ROOM  Others  ANG MO KIO AVE 10            67.0
# 44      1  ANG MO KIO    3 ROOM  Others  ANG MO KIO AVE 10            67.0
# 45      1  ANG MO KIO    3 ROOM  Others  ANG MO KIO AVE 10            67.0
# 46      1  ANG MO KIO    3 ROOM  Others  ANG MO KIO AVE 10            82.0
# 47      1  ANG MO KIO    3 ROOM  Others  ANG MO KIO AVE 10            67.0
# 48      1  ANG MO KIO    3 ROOM  Others  ANG MO KIO AVE 10            83.0
# 49      1  ANG MO KIO    3 ROOM     435  ANG MO KIO AVE 10            67.0
# 50      1  ANG MO KIO    3 ROOM     435  ANG MO KIO AVE 10            67.0
# 51      1  ANG MO KIO    3 ROOM  Others  ANG MO KIO AVE 10            67.0
# 52      1  ANG MO KIO    3 ROOM  Others  ANG MO KIO AVE 10            67.0
# 53      1  ANG MO KIO    3 ROOM     424   ANG MO KIO AVE 3            73.0
# 54      1  ANG MO KIO    3 ROOM     424   ANG MO KIO AVE 3            73.0
#
#         flat_model  lease_commence_date  resale_price  remaining_lease  year  \
# 0         Improved                 1977        9000.0               86  1990
# 1         Improved                 1977        6000.0               86  1990
# 2         Improved                 1977        8000.0               86  1990
# 3         Improved                 1977        6000.0               86  1990
# 4   New Generation                 1976       47200.0               85  1990
# 5   New Generation                 1977       46000.0               86  1990
# 6   New Generation                 1977       42000.0               86  1990
# 7   New Generation                 1977       38000.0               86  1990
# 8   New Generation                 1977       40000.0               86  1990
# 9   New Generation                 1977       47000.0               86  1990
# 10  New Generation                 1977       43000.0               86  1990
# 11  New Generation                 1976       59000.0               85  1990
# 12  New Generation                 1976       47200.0               85  1990
# 13  New Generation                 1977       35000.0               86  1990
# 14  New Generation                 1977       52000.0               86  1990
# 15  New Generation                 1978       56900.0               87  1990
# 16  New Generation                 1977       40000.0               86  1990
# 17  New Generation                 1977       40000.0               86  1990
# 18  New Generation                 1978       47200.0               87  1990
# 19  New Generation                 1978       37000.0               87  1990
# 20  New Generation                 1978       60000.0               87  1990
# 21  New Generation                 1978       40000.0               87  1990
# 22  New Generation                 1978       41000.0               87  1990
# 23  New Generation                 1978       37000.0               87  1990
# 24  New Generation                 1978       34000.0               87  1990
# 25  New Generation                 1978       47000.0               87  1990
# 26  New Generation                 1978       36000.0               87  1990
# 27  New Generation                 1978       45000.0               87  1990
# 28  New Generation                 1978       44000.0               87  1990
# 29  New Generation                 1979       44000.0               88  1990
# 30  New Generation                 1979       50000.0               88  1990
# 31  New Generation                 1978       47000.0               87  1990
# 32  New Generation                 1978       47200.0               87  1990
# 33  New Generation                 1978       58000.0               87  1990
# 34  New Generation                 1979       45000.0               88  1990
# 35  New Generation                 1979       44000.0               88  1990
# 36  New Generation                 1979       47000.0               88  1990
# 37  New Generation                 1979       53000.0               88  1990
# 38  New Generation                 1979       47000.0               88  1990
# 39  New Generation                 1979       44000.0               88  1990
# 40  New Generation                 1979       47000.0               88  1990
# 41  New Generation                 1979       47000.0               88  1990
# 42  New Generation                 1979       45000.0               88  1990
# 43  New Generation                 1979       40000.0               88  1990
# 44  New Generation                 1979       47000.0               88  1990
# 45  New Generation                 1979       42000.0               88  1990
# 46  New Generation                 1979       56000.0               88  1990
# 47  New Generation                 1979       36000.0               88  1990
# 48  New Generation                 1979       48000.0               88  1990
# 49  New Generation                 1979       47200.0               88  1990
# 50  New Generation                 1979       37000.0               88  1990
# 51  New Generation                 1979       45000.0               88  1990
# 52  New Generation                 1979       37000.0               88  1990
# 53  New Generation                 1979       34000.0               88  1990
# 54  New Generation                 1979       40000.0               88  1990
#
#     storey_start  storey_end  floor_area_sq_ft  age_of_property  Floor_median
# 0             10          12               333               13            11
# 1              4           6               333               13             5
# 2             10          12               333               13            11
# 3              7           9               333               13             8
# 4              4           6               785               14             5
# 5              1           3               721               13             2
# 6              7           9               721               13             8
# 7             10          12               721               13            11
# 8              4           6               721               13             5
# 9              1           3               721               13             2
# 10             7           9               721               13             8
# 11             7           9               882               14             8
# 12            10          12               721               14            11
# 13             7           9               721               13             8
# 14             7           9               882               13             8
# 15             4           6               882               12             5
# 16             7           9               785               13             8
# 17             7           9               721               13             8
# 18             4           6               721               12             5
# 19            10          12               721               12            11
# 20             7           9               882               12             8
# 21             7           9               785               12             8
# 22            10          12               785               12            11
# 23             4           6               796               12             5
# 24            10          12               721               12            11
# 25             7           9               785               12             8
# 26             4           6               785               12             5
# 27            10          12               785               12            11
# 28             4           6               721               12             5
# 29             4           6               785               11             5
# 30             1           3               947               11             2
# 31             7           9               721               12             8
# 32             7           9               721               12             8
# 33            10          12               882               12            11
# 34            10          12               721               11            11
# 35            10          12               721               11            11
# 36             4           6               721               11             5
# 37            13          15               957               11            14
# 38             4           6               796               11             5
# 39             7           9               796               11             8
# 40             7           9               796               11             8
# 41             7           9               721               11             8
# 42             4           6               721               11             5
# 43             7           9               721               11             8
# 44             7           9               721               11             8
# 45             7           9               721               11             8
# 46             4           6               882               11             5
# 47            10          12               721               11            11
# 48             1           3               893               11             2
# 49             1           3               721               11             2
# 50             1           3               721               11             2
# 51             7           9               721               11             8
# 52             7           9               721               11             8
# 53            10          12               785               11            11
# 54             1           3               785               11             2

# %% [markdown]
# # Define the number of columns and rows for the subplot grid
# num_cols = 7
# num_rows = 1
#
# # Create subplots
# fig, axes = plt.subplots(num_rows, num_cols, figsize=(8,20))
#
# # Flatten the axes array for easy indexing
# #axes = axes.flatten()
#
# # Loop through the DataFrame columns and plot
# for i, column in enumerate(df_iso.columns):
#     sns.boxplot(data =df_iso, y=df_iso[column], ax=axes[i])  # Replace with desired plot type
#     axes[i].set_title(f'{column} after Isolationforest')
#
# # Adjust layout
# plt.tight_layout()
# plt.show()

# %% [markdown]
# # Define the number of columns and rows for the subplot grid
# num_cols = 1
# num_rows = 7
#
# # Create subplots
# fig, axes = plt.subplots(num_rows, num_cols, figsize=(8,20))
#
# # Flatten the axes array for easy indexing
# #axes = axes.flatten()
#
# # Loop through the DataFrame columns and plot
# for i, column in enumerate(df_iso.columns):
#     sns.distplot(df_iso[column], ax=axes[i])  # Replace with desired plot type
#     axes[i].set_title(f'{column} after Isolationforest')
#
# # Adjust layout
# plt.tight_layout()
# plt.show()

# %%
df['age_of_property'].value_counts()
# Out:
# age_of_property
# 5     51669
# 4     50421
# 6     38727
# 10    34466
# 13    34409
# 14    34310
# 11    34210
# 12    33564
# 9     33124
# 7     32571
# 15    31436
# 8     31420
# 16    29941
# 17    29186
# 18    28682
# 20    28342
# 19    28118
# 21    27515
# 22    25396
# 23    24303
# 24    22494
# 25    21542
# 26    19593
# 27    18064
# 28    16721
# 29    15454
# 30    14602
# 31    14056
# 32    13025
# 33    12447
# 34    12112
# 35    11298
# 36    10620
# 37     9402
# 3      9175
# 38     8593
# 39     7554
# 40     6155
# 41     5039
# 42     4591
# 43     4359
# 44     3780
# 45     3160
# 46     2647
# 47     2049
# 48     1690
# 49     1281
# 50     1061
# 51      780
# 52      728
# 53      585
# 2       533
# 54      446
# 55      230
# 1       211
# 56      125
# 57      104
# 58        2
# Name: count, dtype: int64

# %%
##data transformation using log function


df['resale_price'] = np.log(df['resale_price'])
sns.distplot(df['resale_price'])
plt.show()

df['lease_commence_date'] = np.log(df['lease_commence_date'])
sns.distplot(df['lease_commence_date'])
plt.show()


df['Floor_median'] = np.log(df['Floor_median'])
sns.distplot(df['Floor_median'])
plt.show()

df['remaining_lease'] = np.log(df['remaining_lease'])
sns.distplot(df['remaining_lease'])
plt.show()

df['age_of_property'] = np.log(df['age_of_property'])
sns.distplot(df['age_of_property'])
plt.show()

df['floor_area_sq_ft'] = np.log(df['floor_area_sq_ft'])
sns.distplot(df['floor_area_sq_ft'])
plt.show()

# %%
Numericaldata_ = ['lease_commence_date', 'resale_price', 'remaining_lease', 'Floor_median', 'age_of_property', 'floor_area_sq_ft']
new_df_ = df[Numericaldata_]
new_df_.head()
# Out:
#    lease_commence_date  resale_price  remaining_lease  Floor_median  \
# 0             7.589336      9.104980         4.454347      2.397895
# 1             7.589336      8.699515         4.454347      1.609438
# 2             7.589336      8.987197         4.454347      2.397895
# 3             7.589336      8.699515         4.454347      2.079442
# 4             7.588830     10.762149         4.442651      1.609438
#
#    age_of_property  floor_area_sq_ft
# 0         2.564949          5.808142
# 1         2.564949          5.808142
# 2         2.564949          5.808142
# 3         2.564949          5.808142
# 4         2.639057          6.665684

# %%
print(new_df_.columns)
# Out:
# Index(['lease_commence_date', 'resale_price', 'remaining_lease',
#        'Floor_median', 'age_of_property', 'floor_area_sq_ft'],
#       dtype='object')

# %%
# Define the number of columns and rows for the subplot grid
num_cols = 6
num_rows = 1

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15,5))

# Flatten the axes array for easy indexing
#axes = axes.flatten()

# Loop through the DataFrame columns and plot
for i, column in enumerate(new_df_.columns):
    sns.boxplot(data =new_df_, y=new_df_[column], ax=axes[i])  # Replace with desired plot type
    axes[i].set_title(f'{column} after log')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
def outlier(df, column):
   
    # Step 1: Calculate Q1, Q3, and IQR
    Q1 = df[column].quantile(0.25)
    Q3 = df[column].quantile(0.75)
    IQR = Q3 - Q1
    
    # Step 2: Identify outliers
    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR
    
    # If you prefer to cap the outliers instead of removing:
    df[column] = df[column].clip(lower=lower_bound, upper=upper_bound)
# Filter out the outliers
    #df[column] = df[df[column] >= lower_bound & df[column] <= upper_bound ]

# %%
outlier(df,'remaining_lease')
outlier(df,'lease_commence_date')
outlier(df,'resale_price')
outlier(df,'Floor_median')
outlier(df,'age_of_property')
outlier(df,'floor_area_sq_ft')

# %%
df.shape
# Out:
# (938118, 16)

# %%
Outliers = ['lease_commence_date', 'remaining_lease', 'resale_price', 'Floor_median','age_of_property', 'floor_area_sq_ft']
df_o = df[Outliers]
df_o.head()
# Out:
#    lease_commence_date  remaining_lease  resale_price  Floor_median  \
# 0             7.589336         4.454347     11.029872      2.397895
# 1             7.589336         4.454347     11.029872      1.609438
# 2             7.589336         4.454347     11.029872      2.397895
# 3             7.589336         4.454347     11.029872      2.079442
# 4             7.588830         4.442651     11.029872      1.609438
#
#    age_of_property  floor_area_sq_ft
# 0         2.564949          6.009226
# 1         2.564949          6.009226
# 2         2.564949          6.009226
# 3         2.564949          6.009226
# 4         2.639057          6.665684

# %%
# Define the number of columns and rows for the subplot grid
num_cols = 6
num_rows = 1

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(15,5))

# Flatten the axes array for easy indexing
#axes = axes.flatten()

# Loop through the DataFrame columns and plot
for i, column in enumerate(df_o.columns):
    sns.boxplot(data =df_o, y=df_o[column], ax=axes[i])  # Replace with desired plot type
    axes[i].set_title(f'{column} after IQR')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
Numericaldata_final = ['month', 'lease_commence_date', 'resale_price', 'remaining_lease', 'year', 'floor_area_sq_ft','Floor_median', 'age_of_property']
df_final= df[Numericaldata_final]

# %%
# Define the number of columns and rows for the subplot grid
num_cols = 8
num_rows = 1

# Create subplots
fig, axes = plt.subplots(num_rows, num_cols, figsize=(20,5))

# Flatten the axes array for easy indexing
#axes = axes.flatten()

# Loop through the DataFrame columns and plot
for i, column in enumerate(df_final.columns):
    sns.boxplot(data =df_final, y=df_final[column], ax=axes[i])  # Replace with desired plot type
    axes[i].set_title(f'{column}_final data')

# Adjust layout
plt.tight_layout()
plt.show()

# %%
df.columns
# Out:
# Index(['month', 'town', 'flat_type', 'block', 'street_name', 'floor_area_sqm',
#        'flat_model', 'lease_commence_date', 'resale_price', 'remaining_lease',
#        'year', 'storey_start', 'storey_end', 'floor_area_sq_ft',
#        'age_of_property', 'Floor_median'],
#       dtype='object')

# %%
#drop the columns 
#df.drop(columns=['storey_start','storey_end'],inplace=True)

# %%
df.head()
# Out:
#    month        town flat_type block       street_name  floor_area_sqm  \
# 0      1  ANG MO KIO    Others   309  ANG MO KIO AVE 1            31.0
# 1      1  ANG MO KIO    Others   309  ANG MO KIO AVE 1            31.0
# 2      1  ANG MO KIO    Others   309  ANG MO KIO AVE 1            31.0
# 3      1  ANG MO KIO    Others   309  ANG MO KIO AVE 1            31.0
# 4      1  ANG MO KIO    3 ROOM   216  ANG MO KIO AVE 1            73.0
#
#        flat_model  lease_commence_date  resale_price  remaining_lease  year  \
# 0        Improved             7.589336     11.029872         4.454347  1990
# 1        Improved             7.589336     11.029872         4.454347  1990
# 2        Improved             7.589336     11.029872         4.454347  1990
# 3        Improved             7.589336     11.029872         4.454347  1990
# 4  New Generation             7.588830     11.029872         4.442651  1990
#
#    storey_start  storey_end  floor_area_sq_ft  age_of_property  Floor_median
# 0            10          12          6.009226         2.564949      2.397895
# 1             4           6          6.009226         2.564949      1.609438
# 2            10          12          6.009226         2.564949      2.397895
# 3             7           9          6.009226         2.564949      2.079442
# 4             4           6          6.665684         2.639057      1.609438

# %%
#use ordinal encoder to convert categorical data into numerical data.
from sklearn.preprocessing import OrdinalEncoder
OE = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)

df['town'] = OE.fit_transform(df[['town']])
print(df)
OE1 = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
df['flat_type'] = OE1.fit_transform(df[['flat_type']])

OE2 = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
df['block'] = OE2.fit_transform(df[['block']])

OE3 = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
df['street_name'] = OE3.fit_transform(df[['street_name']])

OE4 = OrdinalEncoder(handle_unknown='use_encoded_value', unknown_value=-1)
df['flat_model'] = OE4.fit_transform(df[['flat_model']])
# Out:
#         month  town flat_type   block       street_name  floor_area_sqm  \
# 0           1   0.0    Others     309  ANG MO KIO AVE 1            31.0
# 1           1   0.0    Others     309  ANG MO KIO AVE 1            31.0
# 2           1   0.0    Others     309  ANG MO KIO AVE 1            31.0
# 3           1   0.0    Others     309  ANG MO KIO AVE 1            31.0
# 4           1   0.0    3 ROOM     216  ANG MO KIO AVE 1            73.0
# ...       ...   ...       ...     ...               ...             ...
# 938264     10  23.0    5 ROOM  Others            Others           122.0
# 938265     10  23.0    Others  Others            Others           164.0
# 938266     10  23.0    Others  Others            Others           164.0
# 938267     10  23.0    Others  Others    YISHUN RING RD           145.0
# 938268     10  23.0    Others  Others            Others           142.0
#
#             flat_model  lease_commence_date  resale_price  remaining_lease  \
# 0             Improved             7.589336     11.029872         4.454347
# 1             Improved             7.589336     11.029872         4.454347
# 2             Improved             7.589336     11.029872         4.454347
# 3             Improved             7.589336     11.029872         4.454347
# 4       New Generation             7.588830     11.029872         4.442651
# ...                ...                  ...           ...              ...
# 938264        Improved             7.594381     13.444447         4.430817
# 938265       Apartment             7.596894     13.815511         4.430817
# 938266       Apartment             7.596894     13.810498         4.430817
# 938267      Maisonette             7.594884     13.697727         4.430817
# 938268       Apartment             7.594381     13.795308         4.430817
#
#         year  storey_start  storey_end  floor_area_sq_ft  age_of_property  \
# 0       1990            10          12          6.009226         2.564949
# 1       1990             4           6          6.009226         2.564949
# 2       1990            10          12          6.009226         2.564949
# 3       1990             7           9          6.009226         2.564949
# 4       1990             4           6          6.665684         2.639057
# ...      ...           ...         ...               ...              ...
# 938264  2024             4           6          7.180070         3.610918
# 938265  2024            10          12          7.475906         3.465736
# 938266  2024             4           6          7.475906         3.465736
# 938267  2024             1           3          7.352441         3.583519
# 938268  2024            10          12          7.331715         3.610918
#
#         Floor_median
# 0           2.397895
# 1           1.609438
# 2           2.397895
# 3           2.079442
# 4           1.609438
# ...              ...
# 938264      1.609438
# 938265      2.397895
# 938266      1.609438
# 938267      0.693147
# 938268      2.397895
#
# [938118 rows x 16 columns]

# %%
df['town'].value_counts()
# Out:
# town
# 20.0    80694
# 23.0    70785
# 11.0    67431
# 1.0     67174
# 22.0    66321
# 0.0     52517
# 9.0     51315
# 3.0     45128
# 6.0     38826
# 4.0     34743
# 14.0    33444
# 18.0    33354
# 21.0    31870
# 16.0    29060
# 8.0     28467
# 7.0     28268
# 5.0     28038
# 12.0    27612
# 10.0    25010
# 19.0    23008
# 15.0    21489
# 2.0     21422
# 13.0    17923
# 17.0    14219
# Name: count, dtype: int64

# %%
df['flat_type'].value_counts()
# Out:
# flat_type
# 1.0    357088
# 0.0    298695
# 2.0    197995
# 3.0     84340
# Name: count, dtype: int64

# %%
df['block'].value_counts()
# Out:
# block
# 321.0    430091
# 86.0       4620
# 0.0        4079
# 12.0       3442
# 2.0        3429
#           ...
# 136.0      1013
# 135.0      1008
# 300.0      1007
# 241.0      1006
# 277.0      1000
# Name: count, Length: 322, dtype: int64

# %%
df['street_name'].value_counts()
# Out:
# street_name
# 16.0    776559
# 20.0     17742
# 7.0      14833
# 1.0      13913
# 2.0      12240
# 11.0      9419
# 18.0      8350
# 6.0       7627
# 5.0       7526
# 3.0       7274
# 15.0      6698
# 13.0      6639
# 4.0       6469
# 14.0      5583
# 8.0       5563
# 17.0      5561
# 9.0       5430
# 12.0      5370
# 10.0      5118
# 0.0       5115
# 19.0      5089
# Name: count, dtype: int64

# %%
df['flat_model'].value_counts()
# Out:
# flat_model
# 5.0     269422
# 3.0     244416
# 8.0     190273
# 11.0     57962
# 10.0     47976
# 12.0     42800
# 1.0      35798
# 4.0      29945
# 7.0      10275
# 2.0       3426
# 9.0       2462
# 6.0       2093
# 0.0       1270
# Name: count, dtype: int64

# %%
df['block'].value_counts()
# Out:
# block
# 321.0    430091
# 86.0       4620
# 0.0        4079
# 12.0       3442
# 2.0        3429
#           ...
# 136.0      1013
# 135.0      1008
# 300.0      1007
# 241.0      1006
# 277.0      1000
# Name: count, Length: 322, dtype: int64

# %%
df.drop(columns=['storey_start','storey_end'],inplace=True)

# %%
df.dtypes
# Out:
# month                    int64
# town                   float64
# flat_type              float64
# block                  float64
# street_name            float64
# floor_area_sqm         float64
# flat_model             float64
# lease_commence_date    float64
# resale_price           float64
# remaining_lease        float64
# year                     int64
# floor_area_sq_ft       float64
# age_of_property        float64
# Floor_median           float64
# dtype: object

# %%
df.drop(columns=['floor_area_sqm', 'lease_commence_date', 'year'],inplace=True)

# %%
sns.heatmap((df).corr(), cmap='coolwarm', annot=True)
plt.show()

# %%
## Regression modelling

# %% [markdown]
# ###### df.columns

# %%
#split data into X, y
x=df[['town','flat_type', 'block', 'flat_model', 'remaining_lease', 'floor_area_sq_ft', 'age_of_property', 'Floor_median','street_name']]
y=df['resale_price']

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaler.fit(x)
scaler.transform(x)
# Out:
# array([[-1.55057913,  2.05031915, -0.53141142, ..., -0.17396452,
#          0.8267497 , -4.11124896],
#        [-1.55057913,  2.05031915, -0.53141142, ..., -0.17396452,
#         -0.32200245, -4.11124896],
#        [-1.55057913,  2.05031915, -0.53141142, ..., -0.17396452,
#          0.8267497 , -4.11124896],
#        ...,
#        [ 1.46183509,  2.05031915,  0.84777568, ...,  1.14938622,
#         -0.32200245,  0.30534454],
#        [ 1.46183509,  2.05031915,  0.84777568, ...,  1.32242196,
#         -1.65700293,  1.40949292],
#        [ 1.46183509,  2.05031915,  0.84777568, ...,  1.36267395,
#          0.8267497 ,  0.30534454]])

# %%
df.shape
# Out:
# (938118, 11)

# %%
#df['target_binned'] = pd.qcut(df['resale_price'], q=20, labels=False)
df['target_binned_'] = pd.qcut(df['resale_price'], q=10, labels=False)

# %%
x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, stratify=df['target_binned_'])
#x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, stratify=df['target_binned_'])

# %%
x_train.head()
# Out:
#         town  flat_type  block  flat_model  remaining_lease  floor_area_sq_ft  \
# 904286  22.0        3.0  321.0         5.0         4.430817          6.224558
# 382611   5.0        1.0  265.0         5.0         4.553877          7.010312
# 378517  23.0        0.0  321.0         5.0         4.430817          6.665684
# 734567  23.0        1.0  219.0         5.0         4.317488          7.020191
# 103225   5.0        0.0    7.0         5.0         4.521789          6.665684
#
#         age_of_property  Floor_median  street_name
# 904286         1.609438      1.609438         16.0
# 382611         1.386294      2.833213         16.0
# 378517         2.708050      2.079442         16.0
# 734567         3.135494      0.693147         20.0
# 103225         1.945910      0.693147         16.0

# %%
x_train.shape
# Out:
# (750494, 9)

# %%
x_test.shape
# Out:
# (187624, 9)

# %%
y_train.shape
# Out:
# (750494,)

# %%
y_test.shape
# Out:
# (187624,)

# %%
lin = LinearRegression()
lin.fit(x_train, y_train)
train_pred = lin.predict(x_train)
mse_train = math.sqrt(mean_squared_error(y_train, train_pred))
pred = lin.predict(x_test)
mse_test = math.sqrt(mean_squared_error(y_test, pred))
r2_train = r2_score(y_train, train_pred)
r2_test = r2_score(y_test, pred)
print(f'RMSE: {mse_train, mse_test}')
print(f'R2: {r2_train, r2_test}')
# Out:
# RMSE: (0.42874075199436273, 0.4283670153945517)
# R2: (0.45346853881065374, 0.45309503049104616)

# %%
from sklearn.tree import DecisionTreeRegressor
import sklearn
dc_r = DecisionTreeRegressor()
dc_r.fit(x_train, y_train)
train_pred = dc_r.predict(x_train)
mse_train = math.sqrt(mean_squared_error(y_train, train_pred))
pred = dc_r.predict(x_test)
mse_test = math.sqrt(mean_squared_error(y_test, pred))
r2_train = r2_score(y_train, train_pred)
r2_test = r2_score(y_test, pred)
print(f'RMSE: {mse_train, mse_test}')
print(f'R2: {r2_train, r2_test}')
# Out:
# RMSE: (0.07857256281559115, 0.14636043759867917)
# R2: (0.9816444469516316, 0.9361549511771734)

# %%
dc_ = DecisionTreeRegressor(max_depth= 20, min_samples_split= 8)
dc_.fit(x_train, y_train)
train_pred = dc_.predict(x_train)
mse_train = math.sqrt(mean_squared_error(y_train, train_pred))
pred = dc_.predict(x_test)
mse_test = math.sqrt(mean_squared_error(y_test, pred))
r2_train = r2_score(y_train, train_pred)
r2_test = r2_score(y_test, pred)
print(f'RMSE: {mse_train, mse_test}')
print(f'R2: {r2_train, r2_test}')
# Out:
# RMSE: (0.12345861049893785, 0.14802344392702133)
# R2: (0.9546822430275265, 0.9346958421176949)

# %%
dc_c= DecisionTreeRegressor(max_depth= 12, min_samples_split= 8)
from sklearn.model_selection import cross_val_score
scores = cross_val_score(dc_c, x_train, y_train, cv=5, scoring='neg_mean_squared_error')
mse_scores = -scores
print("Mean Squared Error for each fold:", mse_scores)
print("Average MSE:", mse_scores.mean())
# Out:
# Mean Squared Error for each fold: [0.04801632 0.04809502 0.04760641 0.04738339 0.04733229]
# Average MSE: 0.04768668567269089

# %%
dc_c.fit(x,y)
# Out:
# DecisionTreeRegressor(max_depth=12, min_samples_split=8)

# %%
from sklearn.model_selection import GridSearchCV
Ss = {'max_depth': [3,4,7,9,10,12,14,16, 20,24,26], 'min_samples_split': [4,6,8,10,12]}
grid = GridSearchCV(dc_r, param_grid=Ss, cv=8)
grid_search = grid.fit(x,y)
print(grid_search.best_params_)
# Out:
# {'max_depth': 20, 'min_samples_split': 12}

# %%
rf = RandomForestRegressor(max_depth= 20, min_samples_split= 8)
rf.fit(x_train, y_train)
train_pred = rf.predict(x_train)
mse_train = math.sqrt(mean_squared_error(y_train, train_pred))
pred = rf.predict(x_test)
mse_test = math.sqrt(mean_squared_error(y_test, pred))
r2_train = r2_score(y_train, train_pred)
r2_test = r2_score(y_test, pred)
print(f'RMSE: {mse_train, mse_test}')
print(f'R2: {r2_train, r2_test}')
# Out:
# RMSE: (0.11787324599898799, 0.1318125154305759)
# R2: (0.9586903632189305, 0.9482084558898201)

# %%
pred
# Out:
# array([12.83867809, 12.74976373, 12.35243074, ..., 12.47401751,
#        13.02034363, 12.6263495 ])

# %%
from sklearn.linear_model import Lasso, Ridge
rid = Ridge(alpha = 1)
rid.fit(x_train, y_train)
train_pred = rid.predict(x_train)
mse_train = math.sqrt(mean_squared_error(y_train, train_pred))
pred = rid.predict(x_test)
mse_test = math.sqrt(mean_squared_error(y_test, pred))
r2_train = r2_score(y_train, train_pred)
r2_test = r2_score(y_test, pred)
print(f'RMSE: {mse_train, mse_test}')
print(f'R2: {r2_train, r2_test}')
# Out:
# RMSE: (0.4006394247417377, 0.4007283699402119)
# R2: (0.5227694283750715, 0.5213194922730098)

# %%
rlass = Lasso(alpha = 12)
rlass.fit(x_train, y_train)
train_pred = rlass.predict(x_train)
mse_train = math.sqrt(mean_squared_error(y_train, train_pred))
pred = rlass.predict(x_test)
mse_test = math.sqrt(mean_squared_error(y_test, pred))
r2_train = r2_score(y_train, train_pred)
r2_test = r2_score(y_test, pred)
print(f'RMSE: {mse_train, mse_test}')
print(f'R2: {r2_train, r2_test}')
# Out:
# RMSE: (0.5799486677415344, 0.5791982262044245)
# R2: (0.0, -2.2383567221950784e-08)

# %%
df1 = df.sample(frac=0.5, random_state=1)  # Randomly select 50% of the data for df1
df2 = df.drop(df1.index)

# %%
df1.shape
# Out:
# (469109, 12)

# %%
df1['target_binned_'] = pd.qcut(df1['resale_price'], q=10, labels=False)

# %%
#split data into X, y
x1=df1[['town','flat_type', 'block', 'flat_model', 'remaining_lease', 'floor_area_sq_ft', 'age_of_property', 'Floor_median','street_name']]
y1=df1['resale_price']

# %%
x_train1, x_test1, y_train1, y_test1 = train_test_split(x1,y1, test_size = 0.3, stratify=df1['target_binned_'])
#x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, stratify=df['target_binned_'])

# %%
dc_1 = DecisionTreeRegressor(max_depth= 20, min_samples_split= 8)
dc_1.fit(x_train1, y_train1)
train_pred = dc_1.predict(x_train1)
mse_train1 = math.sqrt(mean_squared_error(y_train1, train_pred))
pred = dc_1.predict(x_test1)
mse_test1 = math.sqrt(mean_squared_error(y_test1, pred))
r2_train1 = r2_score(y_train1, train_pred)
r2_test1 = r2_score(y_test1, pred)
print(f'RMSE: {mse_train1, mse_test1}')
print(f'R2: {r2_train1, r2_test1}')
# Out:
# RMSE: (0.12220507359153933, 0.15654805270817332)
# R2: (0.9555486704261192, 0.9271302907095028)

# %%
# Predict the status for a new sample


input_data = {
  
   'town': ['ANG MO KIO'],
   'flat_type': ['2 ROOM'],
   'block': ['172'],
   'flat_model': ['Improved'],
#'lease_commence_date': [1986],
   'remaining_lease': [73.0],
   'floor_area_sq_ft': [450],
   'age_of_property': [26],
   'Floor_median': [8.0],
#'year': [2012],
    'street_name' : ['ANG MO KIO AVE 4'],
#'storey_start': [6],
#'storey_end': [10]
}

input_data = pd.DataFrame(input_data)

#use ordinal encoder to convert categorical data into numerical data.

input_data['town'] = OE.transform(input_data[['town']])


input_data['flat_type'] = OE1.transform(input_data[['flat_type']])

input_data['block'] = OE2.transform(input_data[['block']])

input_data['flat_model'] = OE4.transform(input_data[['flat_model']])

input_data['street_name'] = OE3.transform(input_data[['street_name']])

#input_data['lease_commence_date'] = np.log(input_data['lease_commence_date'])

input_data['remaining_lease'] = np.log(input_data['remaining_lease'])

input_data['Floor_median'] = np.log(input_data['Floor_median'])

input_data['age_of_property'] = np.log(input_data['age_of_property'])

input_data['floor_area_sq_ft'] = np.log(input_data['floor_area_sq_ft'])
##data transformation using log function





input_data_=input_data[['town','flat_type', 'block', 'flat_model', 'remaining_lease', 'floor_area_sq_ft', 'age_of_property', 'Floor_median','street_name']]

input_data_s = scaler.transform(input_data_)     
new_pred = dc_c.predict(input_data_s)
print(new_pred)
print(np.exp(new_pred))
# Out:
# [13.10283634]
# [490331.19058835]

# %%
df2['target_binned_'] = pd.qcut(df2['resale_price'], q=10, labels=False)

# %%
#split data into X, y
x2=df2[['town','flat_type', 'block', 'flat_model', 'remaining_lease', 'floor_area_sq_ft', 'age_of_property', 'Floor_median','street_name']]
y2=df2['resale_price']

# %%
x_train2, x_test2, y_train2, y_test2 = train_test_split(x2,y2, test_size = 0.3, stratify=df2['target_binned_'])
#x_train, x_test, y_train, y_test = train_test_split(x,y, test_size = 0.2, stratify=df['target_binned_'])

# %%
dc_2 = DecisionTreeRegressor(max_depth= 12, min_samples_split= 8)
dc_2.fit(x_train2, y_train2)
train_pred = dc_2.predict(x_train2)
mse_train2 = math.sqrt(mean_squared_error(y_train2, train_pred))
pred = dc_1.predict(x_test2)
mse_test2 = math.sqrt(mean_squared_error(y_test2, pred))
r2_train2 = r2_score(y_train2, train_pred)
r2_test2 = r2_score(y_test2, pred)
print(f'RMSE: {mse_train2, mse_test2}')
print(f'R2: {r2_train2, r2_test2}')
# Out:
# RMSE: (0.2131689907436582, 0.15568362412470413)
# R2: (0.864803494347701, 0.9279962305509861)

# %%
# Predict the status for a new sample


input_data = {
  
   'town': ['ANG MO KIO'],
   'flat_type': ['3 ROOM'],
   'block': ['108'],
   'flat_model': ['New Generation'],
#'lease_commence_date': [1986],
   'remaining_lease': [68.0],
#'floor_area_sqm': [45],
   'age_of_property': [39],
   'Floor_median': [2.0],
#'year': [2017],
    'street_name' : ['ANG MO KIO AVE 4'],
    'floor_area_sq_ft': [450]
}

input_data = pd.DataFrame(input_data)

#use ordinal encoder to convert categorical data into numerical data.

input_data['town'] = OE.transform(input_data[['town']])


input_data['flat_type'] = OE1.transform(input_data[['flat_type']])

input_data['block'] = OE2.transform(input_data[['block']])

input_data['flat_model'] = OE4.transform(input_data[['flat_model']])

input_data['street_name'] = OE3.transform(input_data[['street_name']])

#input_data['lease_commence_date'] = np.log(input_data['lease_commence_date'])

input_data['remaining_lease'] = np.log(input_data['remaining_lease'])

input_data['Floor_median'] = np.log(input_data['Floor_median'])

input_data['age_of_property'] = np.log(input_data['age_of_property'])

input_data['floor_area_sq_ft'] = np.log(input_data['floor_area_sq_ft'])

#input_data['floor_area_sqm'] = np.log(input_data['floor_area_sqm'])
##data transformation using log function





input_data_=input_data[['town','flat_type', 'block', 'flat_model', 'remaining_lease', 'floor_area_sq_ft', 'age_of_property', 'Floor_median','street_name']]

input_data_s = scaler.transform(input_data_)     
new_pred = dc_.predict(input_data_s)
print(new_pred)
print(np.exp(new_pred))
# Out:
# [12.94134804]
# [417211.28124598]

# %%
with open('C:/Users/rajij/Streamlit_Home Page/Singapore flat resale model/dcr.pkl', 'wb') as file:
    pickle.dump(dc_, file)

with open('C:/Users/rajij/Streamlit_Home Page/Singapore flat resale model/OE.pkl', 'wb') as file:
    pickle.dump(OE, file)

with open('C:/Users/rajij/Streamlit_Home Page/Singapore flat resale model/OE1.pkl', 'wb') as file:
    pickle.dump(OE1, file)

with open('C:/Users/rajij/Streamlit_Home Page/Singapore flat resale model/OE2.pkl', 'wb') as file:
    pickle.dump(OE2, file)

with open('C:/Users/rajij/Streamlit_Home Page/Singapore flat resale model/OE3.pkl', 'wb') as file:
    pickle.dump(OE3, file)

with open('C:/Users/rajij/Streamlit_Home Page/Singapore flat resale model/OE4.pkl', 'wb') as file:
    pickle.dump(OE4, file)
    
with open('C:/Users/rajij/Streamlit_Home Page/Singapore flat resale model/scaler.pkl', 'wb') as file:
    pickle.dump(scaler, file)

# %%
from joblib import dump

# Save the model
dump(dc_, 'DCR.joblib')
# Out:
# ['DCR.joblib']

# %%
dump(OE, 'OEJ.joblib')
# Out:
# ['OEJ.joblib']

# %%
dump(OE1, 'OEJ1.joblib')
# Out:
# ['OEJ1.joblib']

# %%
dump(OE2, 'OEJ2.joblib')
# Out:
# ['OEJ2.joblib']

# %%
dump(OE3, 'OEJ3.joblib')
# Out:
# ['OEJ3.joblib']

# %%
dump(OE4, 'OEJ4.joblib')
# Out:
# ['OEJ4.joblib']

# %%
dump(scaler, 'scalerJ.joblib')
# Out:
# ['scalerJ.joblib']
